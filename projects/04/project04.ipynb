# %% [markdown]
# # Project 04: Language Models
#
# ## Checkpoint Due Date (Questions 1-5): Thursday May 20, 11:59 PM
#
# ## Due Date:  Thursday May 27, 11:59 PM

# %% [markdown]
# #### Checkpoint Instructions
# * The checkpoint requires you to turn in questions 1-5.
# * The checkpoint will be graded for approximate correctness: easier than the final tests; harder than the doctests.

# %% [markdown]
# # Introduction to Language Models
#
# In this project, you will build *[statistical language models](https://en.wikipedia.org/wiki/Language_model)* using public domain books found on [Project Gutenberg](https://www.gutenberg.org/). Language models attempt to capture the likelihood that a given sequence of words occur in a given "language" (the precise term is "corpus" or "corpora"). Here, "language" is a broad term that, in addition to the normal usage, may mean the language of a particular author or style. Applications of language models are found in areas such as language generation, authorship attribution, auto-complete / word-suggestion, and machine translation.
#
# In this project, you will learn about a simple but effective type of language model (LM) called N-gram models. Given a sentence (that is, a sequence of words $w = w_1\ldots w_n$), you would like to understand the probability that sentence is used:
# $$P(w) = P(w_1,\ldots,w_n)$$
# However, sentences are built from words, and the likelihood that a word occurs where it does, depends on the words it follows. This points to using *conditional probability* to understand $P(w)$. That is, we can write:
#
# $$
# P(w) = P(w_1,\ldots,w_n) = P(w_1) \cdot P(w_2|w_1) \cdot P(w_3|w_1,w_2) \cdot\ldots\cdot P(w_n|w_1,\ldots,w_{n-1})
# $$
# This is also called the *chain rule* for probabilities.
# **Example:** Consider the sentence $w = $ `when I eat pizza, I wipe off the grease.`
#
# $$
# P(\mbox{when}) \cdot P(\mbox{I | when}) \cdot P(\mbox{ eat | when I})\cdot P(\mbox{ pizza | when I eat}) \cdot \ldots \cdot P(\mbox{ grease | when I eat pizza, I wipe off the})
# $$
#
# That is, the probability that the sentence occurs is the product of the probability that each subsequent word follows the words that came before. For example, the probability $P(\mbox{ pizza | when I eat})$ is pretty high, as pizza is something that you eat; thus, this term would contribute to this sentence having a higher probability of occurrence.
#
# ### N-gram language models
#
# In the description above, the probability that any word in the sentence (e.g. 'grease') depends on *every* word that preceded it (e.g. 'when'). However, it's often the case the likelihood a word appears in a sentence is influenced more by *nearby* words.
# * N-gram language models capture this concept that only nearby words matter; they assume the probability a word occurs only depends on the previous $(N−1)$ words.
# * That is, an N-gram model says: $P(w_n|w_1,\ldots,w_{n-1}) = P(w_n|w_{n-(N-1)},\ldots,w_{n-1})$.
#
# **Example: trigram model**
#
# Consider the sentence $w = $ `when I eat pizza, I wipe off the grease.`
#
# $$
# P(\mbox{when}) \cdot P(\mbox{I | when}) \cdot P(\mbox{ eat | when I})\cdot P(\mbox{ pizza | I eat}) \cdot \ldots \cdot P(\mbox{ the | wipe off}) \cdot P(\mbox{ grease | off the})
# $$
# In this example, we see the trigram model doesn't consider the beginning of the sentence when considering the likelihood of the end word 'grease'.
#
# **Definition:** Given the descriptions and definitions above, we define the **N-grams of a text** to be the list of sliding windows of length N.
#
# For Example, the trigrams of the sentence $w$ in the example above are:
# ```
# [('when', 'I', 'eat'), ('I', 'eat', 'pizza'), ... , ('wipe', 'off', 'the'), ('off', 'the', 'grease')]
# ```
#
# ### Computing an N-gram language model
#
# N-gram language models are a collection of conditional probabilities for sequences of words of length $N$. For example, in a trigram model, for every 3-word sequence $w_1, w_2, w_3$, you need to compute:
# $$P(w_1,w_2,w_3) = P(w_3 | w_1, w_2) = \frac{C(w_1, w_2, w_3)}{C(w_1, w_2)}$$
#
# Where $C(w_1, w_2, w_3)$ is the number of occurrences of the trigram-sequence $w_1, w_2, w_3$ in the dataset and $C(w_1, w_2)$ is the number of occurrences of the bigram-sequence  $w_1, w_2$ in the dataset.
#
# For a general N-gram model, the conditional probabilities are computed by dividing the counts of N-grams by the (N-1)-grams they follow.
#
#
# ### Tokenizing corpora
#
# Computing the probabilities of a language model from a book requires breaking up the text of book into sequences of words. This process is called *tokenization*. In reality though, the sequences are not made up entirely of words, but rather more general terms called *tokens*. In this project tokens will include not only whole words, but also punctuation and other terms. Below are a few examples of other types of tokens:
#
# * Punctuation like `,.;'`. For example, the period makes sense as a token, as certain words tend to end sentences (i.e. come before a `.` in an N-gram) and begin sentences (i.e. come after a `.` in an N-gram).
# * We have special 'START' and 'END' tokens that begin and end every word sequence (in our case, paragraphs of words in a given book). These make sense as tokens, as certain words may tend to begin and end paragraphs.
#
# It is useful for the tokens used to represent START and END to be single characters that can never be found in the text of the book you use to create our language model. Thus, you will use two ascii hidden "[control characters](https://en.wikipedia.org/wiki/C0_and_C1_control_codes#C0_(ASCII_and_derivatives))":
# * For START, you will use the character `\x02` (used for 'beginning of text')
# * For END, you will use the character `\x03` (used for 'end of text')

# %% [markdown]
# ### A note on checking your work for correctness
#
# Building a statistical model involves stringing together difficult-to-follows steps such as data-cleaning and implementing derived mathematical formulas. A fact of life in this line of work is that it can be difficult to assess the correctness of your work.
#
# * The Doctests will include checks on the inputs/outputs of your methods.
# * Doctests will include models on which you can check your work 'by hand'.
# * Additionally, **you should run your functions on *real* books and assess the reasonableness of your result** as well. Merely passing the doctests is never sufficient to guarantee correctness of your code.

# %% [markdown]
# # Project Outline
#
# Below is an outline of the the project. If there are terms you don't understand in following descriptions, you should review the introduction for an explanation of the terms and ideas described.
#
# 1. Write code to download the text of a book from a url, returning the corpus as a string.
# 1. Tokenize the corpus into sequences of words and paragraphs.
# 1. Create two "baseline" langunage models; create text with them using sampling.
# 1. Compute an N-gram language model
# 1. Write code to sample from the N-gram language model; create text with them.
# 1. Evaluate performance (computational) of your language model for different N.
# 1. Evaluate performance (statistical) of your language model for different N.
# 1. Create an auto-completion suggestion model.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import project04 as proj

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import os
import re
import requests
import time

# %% [markdown]
# ## Downloading the book(s)
#
# **Question 1**
#
# For this question, you will use `requests` to download and prepare a public domain book from [Project Gutenberg](). Create a function `get_book` that takes in the `url` of a 'Plain Text UTF-8' book and returns a string containing the contents of the book.
#
# The function should satisfy the following conditions:
# * The contents of the book consist of everything between Project Gutenberg's START and END comments.
# * The contents *will* include title/author/table of contents.
# * You should also transform any Windows new-lines (`\r\n`) with standard new-lines (`\n`).
# * You should check the site's `robots.txt` as well and implement a 'pause' in your request in accordance with the website's policy. If the function is called twice in succession, it should not violate the `robots.txt` policy.
#
# *Note:* You are encouraged to find whatever books on the website that interest you to test your code and the language models you develop. The text doesn't even need to be an English-language book.

# %%
# Get the actual book text
url = 'http://www.gutenberg.org/files/74/74-0.txt'
book_string = proj.get_book(url)

# %%
#url = 'http://www.gutenberg.org/files/57988/57988-0.txt'
r = requests.get(url)

# %%
raw_text = r.text

# %%
start_index = re.search(r'(\*\*\* START OF.+\*\*\*)', raw_text).span()[1]
end_index = re.search(r'(\*\*\* END OF.+\*\*\*)', raw_text).span()[0]

# %%
raw_text[start_index:end_index].replace('\r\n', '\n')
# Out:
# '\n\n\n\n\nTHE ADVENTURES OF TOM SAWYER\n\n\nBy Mark Twain\n\n(Samuel Langhorne Clemens)\n\n\n\n\nCONTENTS\n\n\nCHAPTER I. Y-o-u-u Tom-Aunt Polly Decides Upon her Dutyâ\x80\x94Tom Practices\nMusicâ\x80\x94The Challengeâ\x80\x94A Private Entrance\n\nCHAPTER II. Strong Temptationsâ\x80\x94Strategic Movementsâ\x80\x94The Innocents\nBeguiled\n\nCHAPTER III. Tom as a Generalâ\x80\x94Triumph and Rewardâ\x80\x94Dismal\nFelicityâ\x80\x94Commission and Omission\n\nCHAPTER IV. Mental Acrobaticsâ\x80\x94Attending Sundayâ\x80\x94Schoolâ\x80\x94The\nSuperintendentâ\x80\x94â\x80\x9cShowing offâ\x80\x9dâ\x80\x94Tom Lionized\n\nCHAPTER V. A Useful Ministerâ\x80\x94In Churchâ\x80\x94The Climax\n\nCHAPTER VI. Self-Examinationâ\x80\x94Dentistryâ\x80\x94The Midnight Charmâ\x80\x94Witches and\nDevilsâ\x80\x94Cautious Approachesâ\x80\x94Happy Hours\n\nCHAPTER VII. A Treaty Entered Intoâ\x80\x94Early Lessonsâ\x80\x94A Mistake Made\n\nCHAPTER VIII. Tom Decides on his Courseâ\x80\x94Old Scenes Re-enacted\n\nCHAPTER IX. A Solemn Situationâ\x80\x94Grave Subjects Introducedâ\x80\x94Injun Joe\nExplains\n\nCHAPTER X. The Solemn Oathâ\x80\x94Terror Brings Repentanceâ\x80\x94Mental Punishment\n\nCHAPTER XI. Muff Potter Comes Himselfâ\x80\x94Tomâ\x80\x99s Conscience at Work\n\nCHAPTER XII. Tom Shows his Generosityâ\x80\x94Aunt Polly Weakens\n\nCHAPTER XIII. The Young Piratesâ\x80\x94Going to the Rendezvousâ\x80\x94The Campâ\x80\x94Fire\nTalk\n\nCHAPTER XIV. Camp-Lifeâ\x80\x94A Sensationâ\x80\x94Tom Steals Away from Camp\n\nCHAPTER XV. Tom Reconnoitersâ\x80\x94Learns the Situationâ\x80\x94Reports at Camp\n\nCHAPTER XVI. A Dayâ\x80\x99s Amusementsâ\x80\x94Tom Reveals a Secretâ\x80\x94The Pirates take a\nLessonâ\x80\x94A Night Surpriseâ\x80\x94An Indian War\n\nCHAPTER XVII. Memories of the Lost Heroesâ\x80\x94The Point in Tomâ\x80\x99s Secret\n\nCHAPTER XVIII. Tomâ\x80\x99s Feelings Investigatedâ\x80\x94Wonderful Dreamâ\x80\x94Becky\nThatcher Overshadowedâ\
ghostsâ\x80\x94A Box of Goldâ\x80\x94Bitter Luck\n\nCHAPTER XXVII. Doubts to be Settledâ\x80\x94The Young Detectives\n\nCHAPTER XXVIII. An Attempt at No. Twoâ\x80\x94Huck Mounts Guard\n\nCHAPTER XXIX. The Pic-nicâ\x80\x94Huck on Injun Joeâ\x80\x99s Trackâ\x80\x94The â\x80\x9cRevengeâ\x80\x9d\n Jobâ\x80\x94Aid for the Widow\n\nCHAPTER XXX. The Welshman Reportsâ\x80\x94Huck Under Fireâ\x80\x94The Story Circulated\nâ\x80\x94A New Sensationâ\x80\x94Hope Giving Way to Despair\n\nCHAPTER XXXI. An Exploring Expeditionâ\x80\x94Trouble Commencesâ\x80\x94Lost in the\nCaveâ\x80\x94Total Darknessâ\x80\x94Found but not Saved\n\nCHAPTER XXXII. Tom tells the Story of their Escapeâ\x80\x94Tomâ\x80\x99s Enemy in Safe\nQuarters\n\nCHAPTER XXXIII. The Fate of Injun Joeâ\x80\x94Huck and Tom Compare Notes\nâ\x80\x94An Expedition to the Caveâ\x80\x94Protection Against Ghostsâ\x80\x94â\x80\x9cAn Awful Snug\nPlaceâ\x80\x9dâ\x80\x94A Reception at the Widow Douglasâ\x80\x99s\n\nCHAPTER XXXIV. Springing a Secretâ\x80\x94Mr. Jonesâ\x80\x99 Surprise a Failure\n\nCHAPTER XXXV. A New Order of Thingsâ\x80\x94Poor Huckâ\x80\x94New Adventures Planned\n\n\n\n\nILLUSTRATIONS\n\n\nTom Sawyer\n\nTom at Home\n\nAunt Polly Beguiled\n\nA Good Opportunity\n\nWhoâ\x80\x99s Afraid\n\nLate Home\n\n ...

# %% [markdown]
# ## Tokenizing the Corpus
#
# **Question 2**
#
# Now you need to tokenize the corpus in `book_string` (turn the text into a list of tokens -- i.e. words and punctuation). More specifically, create a function `tokenize` that takes in `book_string` and outputs a list of tokens satisfying the following conditions:
# * The start of any paragraph should be represented in the list with the single character `\x02` (standing for START).
# * The end of any paragraph should be represented in the list with the single character `\x03` (standing for STOP).
# * Tokens in the sequence of words are split apart at 'word boundaries' (see the regex lecture).
# * Tokens should include *no* whitespace.
# * Whitespace (e.g. multiple new-lines) between two paragraphs of text should be ignored.
# * Two or more newlines count as a paragraph break
#
# For example, the following sentence (the ellipses denote preceding/continuing text):
# ```
# ...
# My phone's dead.
#
# I didn't get your call.
# ...
# ```
# should tokenize to:
# ```
# [ ...
# "My", "phone", "'", "s", "dead", ".", "\x03", "\x02", "I", "didn", "'", "t", "get", "your", "call", "."
# ... ]
# ```
#
# *Remark:* Your tokenization function should run quickly; you should avoid loops when possible. Your `tokenize` function should run on the the complete works of Shakespeare (in `data/shakespeare`) in **under 10 seconds** to get full credit. Be sure to only request the book once (using your `get_book` function) and save it to file for testing!

# %%
shakespeare_fp = os.path.join('data', 'shakespeare.txt')
shakespeare = open(shakespeare_fp, encoding='utf-8').read()
len(shakespeare)
# Out:
# 5566689

# %%
test = "My phone's dead. \n\n\n I didn't get your call (haha)."

# %%
test_list = re.split('(\W)', test)
[i for i in test_list if (i != ' ' and i != '')]
# Out:
# ['My',
#  'phone',
#  "'",
#  's',
#  'dead',
#  '.',
#  '\n',
#  '\n',
#  '\n',
#  'I',
#  'didn',
#  "'",
#  't',
#  'get',
#  'your',
#  'call',
#  '(',
#  'haha',
#  ')',
#  '.']

# %%
proj.tokenize(test)
# Out:
# ['\x02',
#  'My',
#  'phone',
#  "'",
#  's',
#  'dead',
#  '.',
#  '\x03',
#  '\x02',
#  'I',
#  'didn',
#  "'",
#  't',
#  'get',
#  'your',
#  'call',
#  '(',
#  'haha',
#  ')',
#  '.',
#  '\x03']

# %%
re.split(r'\n{2,}', book_string)
# Out:
# ['',
#  'THE ADVENTURES OF TOM SAWYER',
#  'By Mark Twain',
#  '(Samuel Langhorne Clemens)',
#  'CONTENTS',
#  'CHAPTER I. Y-o-u-u Tom-Aunt Polly Decides Upon her Dutyâ\x80\x94Tom Practices\nMusicâ\x80\x94The Challengeâ\x80\x94A Private Entrance',
#  'CHAPTER II. Strong Temptationsâ\x80\x94Strategic Movementsâ\x80\x94The Innocents\nBeguiled',
#  'CHAPTER III. Tom as a Generalâ\x80\x94Triumph and Rewardâ\x80\x94Dismal\nFelicityâ\x80\x94Commission and Omission',
#  'CHAPTER IV. Mental Acrobaticsâ\x80\x94Attending Sundayâ\x80\x94Schoolâ\x80\x94The\nSuperintendentâ\x80\x94â\x80\x9cShowing offâ\x80\x9dâ\x80\x94Tom Lionized',
#  'CHAPTER V. A Useful Ministerâ\x80\x94In Churchâ\x80\x94The Climax',
#  'CHAPTER VI. Self-Examinationâ\x80\x94Dentistryâ\x80\x94The Midnight Charmâ\x80\x94Witches and\nDevilsâ\x80\x94Cautious Approachesâ\x80\x94Happy Hours',
#  'CHAPTER VII. A Treaty Entered Intoâ\x80\x94Early Lessonsâ\x80\x94A Mistake Made',
#  'CHAPTER VIII. Tom Decides on his Courseâ\x80\x94Old Scenes Re-enacted',
#  'CHAPTER IX. A Solemn Situationâ\x80\x94Grave Subjects Introducedâ\x80\x94Injun Joe\nExplains',
#  'CHAPTER X. The Solemn Oathâ\x80\x94Terror Brings Repentanceâ\x80\x94Mental Punishment',
#  'CHAPTER XI. Muff Potter Comes Himselfâ\x80\x94Tomâ\x80\x99s Conscience at Work',
#  'CHAPTER XII. Tom Shows his Generosityâ\x80\x94Aunt Polly Weakens',
#  'CHAPTER XIII. The Young Piratesâ\x80\x94Going to the Rendezvousâ\x80\x94The Campâ\x80\x94Fire\nTalk',
#  'CHAPTER XIV. Camp-Lifeâ\x80\x94A Sensationâ\x80\x94Tom Steals Away from Camp',
#  'CHAPTER XV. Tom Reconnoitersâ\x80\x94Learns the Situationâ\x80\x94Reports at Camp',
#  'CHAPTER XVI. A Dayâ\x80\x99s Amusementsâ\x80\x94Tom Reveals a Secretâ\x80\x94The Pirates take a\nLessonâ\x80\x94A Night Surpriseâ\x80\x94An Indian War',
#  'CHAPTER XVII. Memories of the Lost Heroesâ\x80\x94The Point in Tomâ\x80\x99s Secret',
#  'Dampened Ardor',
#  'Youth',
#  'Boyhood',
#  'Using the â\x80\x9cBarlowâ\x80\x9d',
#  'The Church',
#  'Necessities',
#  'Tom as a Sunday-School Hero',
#  'The Prize',
#  'At Church',
#  'The Model Boy',
#  'The Church Choir',
#  'A Side Show',
#  'Result of Playing in Church',
#  'The Pinch-Bug',
#  'Sid',
#  'Dentistry',
#  'Huckleberry Finn',
#  'Mother Hopkins',
#  'Result of Tomâ\x80\x99s Truthfulness',
#  'Tom as an Artist',
#  'Interrupted Courtship',
#  'The Master',
#  'Vain Pleading',
#  'Tail Piece',
#  'The Grave in the Woods',
#  'Tom Meditates',
#  'Robin Hood and his Foe',
#  'Death of Robin Hood',
#  'Midnight',
#  'Tomâ\x80\x99s Mode of Egress',
#  'Tomâ\x80\x99s Effort at Prayer',
#  'Muff Potter Outwitted',
#  'The Graveyard',
#  'Forewarnings',
#  'Disturbing Muffâ\x80\x99s Sleep',
#  'Tomâ\x80\x99s Talk with his Aunt',
#  'Muff Potter',
#  'A Suspicious Incident',
#  'Injun Joeâ\x80\x99s two Victims',
#  'In the Coils',
#  'Peter',
#  'Aunt Polly seeks Information',
#  'A General Good Time',
#  'Demoralized',
#  'Joe Harper',
#  'On Board Their First Prize',
#  'The Pirates Ashore',
#  'Wild Life',
#  'The Pirateâ\x80\x99s Bath',
#  'The Pleasant Stroll',
#  'The Search for the Drowned',
#  'The Mysterious Writing',
#  'River View',
#  'What Tom Saw',
#  'Tom Swims the River',
#  'Taking Lessons',
#  'The Piratesâ\x80\x99 Egg Market',
#  'Tom Looking for Joeâ\x80\x99s Knife',
#  'The Thunder Storm',
#  'Terrible Slaughter',
#  'The Mourner',
#  'Tomâ\x80\x99s Proudest Moment',
#  'Amy Lawrence',
#  'Tom tries to Remember',
#  'The Hero',
#  'A Flirtation',
#  'Becky Retaliates',
#  'A Sudden Frost',
#  'Counter-irritation',
#  'Aunt Polly',
#  'Tom justified',
#  'The Discovery',
#  'Caught in the Act',
#  'Tom Astonishes the School',
#  'Literature',
#  'Tom Declaims',
#  'Examination Evening',
#  'On Exhibition',
#  'Prize Authors',
#  'The Masterâ\x80\x99s Dilemma',
#  'The School House',
#  'The Cadet',
#  'Happy for Two Days',
#  'Enjoying the Vacation',
#  'The Stolen Melons',
#  'The Judge',
#  'Visiting the Prisoner',
#  'Tom Swears',
#  'The Court Room',
#  'The Detective',
#  'Tom Dreams',
#  'The Treasure',
#  'The Private Conference',
#  'A King; Poor Fellow!',
#  'Business',
#  'The Haâ\x80\x99nted House',
#  'Injun Joe',
#  'The Greatest and Best',
#  'Hidden Treasures Unearthed',
#  'The Boyâ\x80\x99s Salvation',
#  'Room No. 2',
#  'The Next Dayâ\x80\x99s Conference',
#  'Treasures',
#  'Uncle Jake',
#  'Buck at Home',
#  'The Haunted Room',
#  'â\x80\x9cRun for Your Lifeâ\x80\x9d',
#  'McDougalâ\x80\x99s Cave',
#  'Inside the Cave',
#  'Huck on Duty',
#  'A Rousing Act',
#  'Tail Piece',
#  'The Welshman',
#  'Result of a Sneeze',
#  'Cornered',
#  'Alarming Discoveries',
#  'Tom and Becky stir up the Town',
#  'Tomâ\x80\x99s Marks',
#  'Huck Questions the Widow',
#  'Vampires',
#  'Wonders of the Cave',
#  'Attacked by Natives',
#  'Despair',
#  'The Wedding Cake',
#  'A New Terror',
#  'Daylight',
#  'â\x80\x9cTurn Outâ\x80\x9d to Receive Tom and Becky',
#  'The Escape from the Cave',
#  'Fate of the Ragged Man',
#  'The Treasures Found',
#  'Caught at Last',
#  'Drop after Drop',
#  'Having a Good Time',
#  'A Business Trip',
#  'â\x80\x9cGot it at Last!â\x80\x9d',
#  'Tail Piece',
#  'Widow Douglas',
#  'Tom Backs his Statement',
#  'Tail Piece',
#  'Huck Transformed',
#  'Comfortable Once More',
#  'High up in Society',
#  'Contentment',
#  'PREFACE',
#  'Most of the adventures recorded in this book really occurred; one or two\nwere experiences of my own, the rest those of boys who were schoolmates\nof mine. Huck Finn is drawn from life; Tom Sawyer also, but not from an\nindividualâ\x80\x94he is a combination of the characteristics of three boys whom\nI knew, and therefore belongs to the composite order of architecture.',
#  'The odd superstitions touched upon were all prevalent among children and\nslaves in the West at the period of this storyâ\x80\x94that is to say, thirty or\nforty years ago.',
#  'Although my book is intended mainly for the entertainment of boys and\ngirls, I hope it will not be shunned by men and women on that account,\nfor part of my plan has been to try to pleasantly remind adults of what\nthey once were themselves, and of how they felt and thought and talked,\nand what queer enterprises they sometimes engaged in.',
#  'THE AUTHOR.',
#  'HARTFORD, 1876.',
#  'CHAPTER I',
#  'â\x80\x9cTOM!â\x80\x9d',
#  'No answer.',
#  'â\x80\x9cTOM!â\x80\x9d',
#  'No answer.',
#  'â\x80\x9cWhatâ\x80\x99s gone with that boy, I wonder? You TOM!â\x80\x9d',
#  'No answer.',
#  'The old lady pulled her spectacles down and looked over them about the\nroom; then she put them up and looked out under them. She seldom or\nnever looked _through_ them for so small a thing as a boy; they were\nher state pair, the pride of her heart, and were built for â\x80\x9cstyle,â\x80\x9d not\nserviceâ\x80\x94she could have seen through a pair of stove-lids just as well.\nShe looked perplexed for a moment, and then said, not fiercely, but\nstill loud enough for the furniture to hear:',
#  'â\x80\x9cWell, I lay if I get hold of you Iâ\x80\x99llâ\x80\x94â\x80\x9d',
#  'She did not finish, for by this time she was bending down and punching\nunder the bed with the broom, and so she needed breath to punctuate the\npunches with. She resurrected nothing but the cat.',
#  'â\x80\x9cI never did see the beat of that boy!â\x80\x9d',
#  'She went to the open door and stood in it and looked out among the\ntomato vines and â\x80\x9cjimpsonâ\x80\x9d weeds that constituted the garden. No Tom. So\nshe lifted up her voice at an angle calculated for distance and shouted:',
#  'â\x80\x9cY-o-u-u TOM!â\x80\x9d',
#  'There was a slight noise behind her and she turned just in time to seize\na small boy by the slack of his roundabout and arrest his flight.',
#  'â\x80\x9cThere! I might â\x80\x99aâ\x80\x99 thought of that closet. What you been doing in\nthere?â\x80\x9d',
#  'â\x80\x9cNothing.â\x80\x9d',
#  'â\x80\x9cNothing! Look at your hands. And look at your mouth. What _is_ that\ntruck?â\x80\x9d',
#  'But it transpired that this was a request which Joe had just been going\nto make of Tom, and had come to hunt him up for that purpose. His mother\nhad whipped him for drinking some cream which he had never tasted and\nknew nothing about; it was plain that she was tired of him and wished\nhim to go; if she felt that way, there was nothing for him to do but\nsuccumb; he hoped she would be happy, and never regret having driven her\npoor boy out into the unfeeling world to suffer and die.',
#  'As the two boys walked sorrowing along, they made a new compact to stand\nby each other and be brothers and never separate till death relieved\nthem of their troubles. Then they began to lay their plans. Joe was for\nbeing a hermit, and living on crusts in a remote cave, and dying,\nsome time, of cold and want and grief; but after listening to Tom, he\nconceded that there were some conspicuous advantages about a life of\ncrime, and so he consented to be a pirate.',
#  'Three miles below St. Petersburg, at a point where the Mississippi River\nwas a trifle over a mile wide, there was a long, narrow, wooded island,\nwith a shallow bar at the head of it, and this offered well as a\nrendezvous. It was not inhabited; it lay far over toward the further\nshore, abreast a dense and almost wholly unpeopled forest. So Jacksonâ\x80\x99s\nIsland was chosen. Who were to be the subjects of their piracies was a\nmatter that did not occur to them. Then they hunted up Huckleberry Finn,\nand he joined them promptly, for all careers were one to him; he was\nindifferent. They presently separated to meet at a lonely spot on the\nriver-bank two miles above the village at the favorite hourâ\x80\x94which was\nmidnight. There was a small log raft there which they meant to capture.\nEach would bring hooks and lines, and such provision as he could steal\nin the most dark and mysterious wayâ\x80\x94as became outlaws. And before the\nafternoon was done, they had all managed to enjoy the sweet glory of\nspreading the fact that pretty soon the town would â\x80\x9chear something.â\x80\x9d All\nwho got this vague hint were cautioned to â\x80\x9cbe mum and wait.â\x80\x9d',
#  'About midnight Tom arrived with a boiled ham and a few trifles,\nand stopped in a dense undergrowth on a small bluff overlooking the\nmeeting-place. It was starlight, and very still. The mighty river lay\nlike an ocean at rest. Tom listened a moment, but no sound disturbed the\nquiet. Then he gave a low, distinct whistle. It was answered from under\nthe bluff. Tom whistled twice more; these signals were answered in the\nsame way. Then a guarded voice said:',
#  'â\x80\x9cWho goes there?â\x80\x9d',
#  'â\x80\x9cTom Sawyer, the Black Avenger of the Spanish Main. Name your names.â\x80\x9d',
#  'â\x80\x9cHuck Finn the Red-Handed, and Joe Harper the Terror of the Seas.â\x80\x9d Tom\nhad furnished these titles, from his favorite literature.',
#  'â\x80\x9câ\x80\x99Tis well. Give the countersign.â\x80\x9d',
#  'Two hoarse whispers delivered the same awful word simultaneously to the\nbrooding night:',
#  'â\x80\x9c_Blood_!â\x80\x9d',
#  'Then Tom tumbled his ham over the bluff and let himself down after it,\ntearing both skin and clothes to some extent in the effort. There was\nan easy, comfortable path along the shore under the bluff, but it lacked\nthe advantages of difficulty and danger so valued by a pirate.',
#  'They built a fire against the side of a great log twenty or thirty steps\nwithin the sombre depths of the forest, and then cooked some bacon in\nthe frying-pan for supper, and used up half of the corn â\x80\x9cponeâ\x80\x9d stock\nthey had brought. It seemed glorious sport to be feasting in that wild,\nfree way in the virgin forest of an unexplored and uninhabited island,\nfar from the haunts of men, and they said they never would return to\ncivilization. The climbing fire lit up their faces and threw its ruddy\nglare upon the pillared tree-trunks of their forest temple, and upon the\nvarnished foliage and festooning vines.',
#  'When the last crisp slice of bacon was gone, and the last allowance\nof corn pone devoured, the boys stretched themselves out on the grass,\nfilled with contentment. They could have found a cooler place, but\nthey would not deny themselves such a romantic feature as the roasting\ncampfire.',
#  'â\x80\x9c_Ainâ\x80\x99t_ it gay?â\x80\x9d said Joe.',
#  'â\x80\x9cItâ\x80\x99s _nuts_!â\x80\x9d said Tom. â\x80\x9cWhat would the boys say if they could see us?â\x80\x9d',
#  'â\x80\x9cSay? Well, theyâ\x80\x99d just die to be hereâ\x80\x94hey, Hucky!â\x80\x9d',
#  'â\x80\x9cI reckon so,â\x80\x9d said Huckleberry; â\x80\x9canyways, Iâ\x80\x99m suited. I donâ\x80\x99t want\nnothing betterâ\x80\x99n this. I donâ\x80\x99t ever get enough to eat, genâ\x80\x99allyâ\x80\x94and here\nthey canâ\x80\x99t come and pick at a feller and bullyrag him so.â\x80\x9d',
#  ...]

# %%
#re.split('(\W)', book_string.replace(r'\n{2,}', ' \x03 \x02 ').replace(r'\n{1}', ' '))
test_list = re.split('(\W)', re.sub(r'\n{2,}', ' \x03 \x02 ', book_string).replace(r'\n{1}', ' '))
[i for i in test_list if (i != ' ' and i != '')][1:-1]
# Out:
# ['\x02',
#  'THE',
#  'ADVENTURES',
#  'OF',
#  'TOM',
#  'SAWYER',
#  '\x03',
#  '\x02',
#  'By',
#  'Mark',
#  'Twain',
#  '\x03',
#  '\x02',
#  '(',
#  'Samuel',
#  'Langhorne',
#  'Clemens',
#  ')',
#  '\x03',
#  '\x02',
#  'CONTENTS',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'I',
#  '.',
#  'Y',
#  '-',
#  'o',
#  '-',
#  'u',
#  '-',
#  'u',
#  'Tom',
#  '-',
#  'Aunt',
#  'Polly',
#  'Decides',
#  'Upon',
#  'her',
#  'Dutyâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Practices',
#  '\n',
#  'Musicâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Challengeâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Private',
#  'Entrance',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'II',
#  '.',
#  'Strong',
#  'Temptationsâ',
#  '\x80',
#  '\x94',
#  'Strategic',
#  'Movementsâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Innocents',
#  '\n',
#  'Beguiled',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'III',
#  '.',
#  'Tom',
#  'as',
#  'a',
#  'Generalâ',
#  '\x80',
#  '\x94',
#  'Triumph',
#  'and',
#  'Rewardâ',
#  '\x80',
#  '\x94',
#  'Dismal',
#  '\n',
#  'Felicityâ',
#  '\x80',
#  '\x94',
#  'Commission',
#  'and',
#  'Omission',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'IV',
#  '.',
#  'Mental',
#  'Acrobaticsâ',
#  '\x80',
#  '\x94',
#  'Attending',
#  'Sundayâ',
#  '\x80',
#  '\x94',
#  'Schoolâ',
#  '\x80',
#  '\x94',
#  'The',
#  '\n',
#  'Superintendentâ',
#  '\x80',
#  '\x94',
#  'â',
#  '\x80',
#  '\x9c',
#  'Showing',
#  'offâ',
#  '\x80',
#  '\x9d',
#  'â',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Lionized',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'V',
#  '.',
#  'A',
#  'Useful',
#  'Ministerâ',
#  '\x80',
#  '\x94',
#  'In',
#  'Churchâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Climax',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VI',
#  '.',
#  'Self',
#  '-',
#  'Examinationâ',
#  '\x80',
#  '\x94',
#  'Dentistryâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Midnight',
#  'Charmâ',
#  '\x80',
#  '\x94',
#  'Witches',
#  'and',
#  '\n',
#  'Devilsâ',
#  '\x80',
#  '\x94',
#  'Cautious',
#  'Approachesâ',
#  '\x80',
#  '\x94',
#  'Happy',
#  'Hours',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VII',
#  '.',
#  'A',
#  'Treaty',
#  'Entered',
#  'Intoâ',
#  '\x80',
#  '\x94',
#  'Early',
#  'Lessonsâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Mistake',
#  'Made',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VIII',
#  '.',
#  'Tom',
#  'Decides',
#  'on',
#  'his',
#  'Courseâ',
#  '\x80',
#  '\x94',
#  'Old',
#  'Scenes',
#  'Re',
#  '-',
#  'enacted',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'IX',
#  '.',
#  'A',
#  'Solemn',
#  'Situationâ',
#  '\x80',
#  '\x94',
#  'Grave',
#  'Subjects',
#  'Introducedâ',
#  '\x80',
#  '\x94',
#  'Injun',
#  'Joe',
#  '\n',
#  'Explains',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'X',
#  '.',
#  'The',
#  'Solemn',
#  'Oathâ',
#  '\x80',
#  '\x94',
#  'Terror',
#  'Brings',
#  'Repentanceâ',
#  '\x80',
#  '\x94',
#  'Mental',
#  'Punishment',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XI',
#  '.',
#  'Muff',
#  'Potter',
#  'Comes',
#  'Himselfâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Conscience',
#  'at',
#  'Work',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XII',
#  '.',
#  'Tom',
#  'Shows',
#  'his',
#  'Generosityâ',
#  '\x80',
#  '\x94',
#  'Aunt',
#  'Polly',
#  'Weakens',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIII',
#  '.',
#  'The',
#  'Young',
#  'Piratesâ',
#  '\x80',
#  '\x94',
#  'Going',
#  'to',
#  'the',
#  'Rendezvousâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Campâ',
#  '\x80',
#  '\x94',
#  'Fire',
#  '\n',
#  'Talk',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIV',
#  '.',
#  'Camp',
#  '-',
#  'Lifeâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Sensationâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Steals',
#  'Away',
#  'from',
#  'Camp',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XV',
#  '.',
#  'Tom',
#  'Reconnoitersâ',
#  '\x80',
#  '\x94',
#  'Learns',
#  'the',
#  'Situationâ',
#  '\x80',
#  '\x94',
#  'Reports',
#  'at',
#  'Camp',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVI',
#  '.',
#  'A',
#  'Dayâ',
#  '\x80',
#  '\x99',
#  's',
#  'Amusementsâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Reveals',
#  'a',
#  'Secretâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Pirates',
#  'take',
#  'a',
#  '\n',
#  'Lessonâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Night',
#  'Surpriseâ',
#  '\x80',
#  '\x94',
#  'An',
#  'Indian',
#  'War',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVII',
#  '.',
#  'Memories',
#  'of',
#  'the',
#  'Lost',
#  'Heroesâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Point',
#  'in',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Secret',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVIII',
#  '.',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Feelings',
#  'Investigatedâ',
#  '\x80',
#  '\x94',
#  'Wonderful',
#  'Dreamâ',
#  '\x80',
#  '\x94',
#  'Becky',
#  '\n',
#  'Thatcher',
#  'Overshadowedâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Becomes',
#  'Jealousâ',
#  '\x80',
#  '\x94',
#  'Black',
#  'Revenge',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIX',
#  '.',
#  'Tom',
#  'Tells',
#  'the',
#  'Truth',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XX',
#  '.',
#  'Becky',
#  'in',
#  'a',
#  'Dilemmaâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Nobility',
#  'Asserts',
#  'Itself',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXI',
#  '.',
#  'Youthful',
#  'Eloquenceâ',
#  '\x80',
#  '\x94',
#  'Compositions',
#  'by',
#  'the',
#  'Young',
#  'Ladiesâ',
#  '\x80',
#  '\x94',
#  'A',
#  '\n',
#  'Lengthy',
#  'Visionâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Boyâ',
#  '\x80',
#  '\x99',
#  's',
#  'Vengeance',
#  'Satisfied',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXII',
#  '.',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Confidence',
#  'Betrayedâ',
#  '\x80',
#  '\x94',
#  'Expects',
#  'Signal',
#  'Punishment',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIII',
#  '.',
#  'Old',
#  'Muffâ',
#  '\x80',
#  '\x99',
#  's',
#  'Friendsâ',
#  '\x80',
#  '\x94',
#  'Muff',
#  'Potter',
#  'in',
#  'Courtâ',
#  '\x80',
#  '\x94',
#  'Muff',
#  'Potter',
#  '\n',
#  'Saved',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIV',
#  '.',
#  'Tom',
#  'as',
#  'the',
#  'Village',
#  'Heroâ',
#  '\x80',
#  '\x94',
#  'Days',
#  'of',
#  'Splendor',
#  'and',
#  'Nights',
#  'of',
#  '\n',
#  'Horrorâ',
#  '\x80',
#  '\x94',
#  'Pursuit',
#  'of',
#  'Injun',
#  'Joe',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXV',
#  '.',
#  'About',
#  'Kings',
#  'and',
#  'Diamondsâ',
#  '\x80',
#  '\x94',
#  'Search',
#  'for',
#  'the',
#  'Treasureâ',
#  '\x80',
#  '\x94',
#  'Dead',
#  '\n',
#  'People',
#  'and',
#  'Ghosts',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVI',
#  '.',
#  'The',
#  'Haunted',
#  'Houseâ',
#  '\x80',
#  '\x94',
#  'Sleepy',
#  'Ghostsâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Box',
#  'of',
#  'Goldâ',
#  '\x80',
#  '\x94',
#  'Bitter',
#  'Luck',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVII',
#  '.',
#  'Doubts',
#  'to',
#  'be',
#  'Settledâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Young',
#  'Detectives',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVIII',
#  '.',
#  'An',
#  'Attempt',
#  'at',
#  'No',
#  '.',
#  'Twoâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'Mounts',
#  'Guard',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIX',
#  '.',
#  'The',
#  'Pic',
#  '-',
#  'nicâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'on',
#  'Injun',
#  'Joeâ',
#  '\x80',
#  '\x99',
#  's',
#  'Trackâ',
#  '\x80',
#  '\x94',
#  'The',
#  'â',
#  '\x80',
#  '\x9c',
#  'Revengeâ',
#  '\x80',
#  '\x9d',
#  '\n',
#  'Jobâ',
#  '\x80',
#  '\x94',
#  'Aid',
#  'for',
#  'the',
#  'Widow',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXX',
#  '.',
#  'The',
#  'Welshman',
#  'Reportsâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'Under',
#  'Fireâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Story',
#  'Circulated',
#  '\n',
#  'â',
#  '\x80',
#  '\x94',
#  'A',
#  'New',
#  'Sensationâ',
#  '\x80',
#  '\x94',
#  'Hope',
#  'Giving',
#  'Way',
#  'to',
#  'Despair',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXI',
#  '.',
#  'An',
#  'Exploring',
#  'Expeditionâ',
#  '\x80',
#  '\x94',
#  'Trouble',
#  'Commencesâ',
#  '\x80',
#  '\x94',
#  'Lost',
#  'in',
#  'the',
#  '\n',
#  'Caveâ',
#  '\x80',
#  '\x94',
#  'Total',
#  'Darknessâ',
#  '\x80',
#  '\x94',
#  'Found',
#  'but',
#  'not',
#  'Saved',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXII',
#  '.',
#  'Tom',
#  'tells',
#  'the',
#  'Story',
#  'of',
#  'their',
#  'Escapeâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Enemy',
#  'in',
#  'Safe',
#  '\n',
#  'Quarters',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXIII',
#  '.',
#  'The',
#  'Fate',
#  'of',
#  'Injun',
#  'Joeâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'and',
#  'Tom',
#  'Compare',
#  'Notes',
#  '\n',
#  'â',
#  '\x80',
#  '\x94',
#  'An',
#  'Expedition',
#  'to',
#  'the',
#  'Caveâ',
#  '\x80',
#  '\x94',
#  'Protection',
#  'Against',
#  'Ghostsâ',
#  '\x80',
#  '\x94',
#  'â',
#  '\x80',
#  '\x9c',
#  'An',
#  'Awful',
#  'Snug',
#  '\n',
#  'Placeâ',
#  '\x80',
#  '\x9d',
#  'â',
#  '\x80',
#  '\x94',
#  'A',
#  'Reception',
#  'at',
#  'the',
#  'Widow',
#  'Douglasâ',
#  '\x80',
#  '\x99',
#  's',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXIV',
#  '.',
#  'Springing',
#  'a',
#  'Secretâ',
#  '\x80',
#  '\x94',
#  'Mr',
#  '.',
#  'Jonesâ',
#  '\x80',
#  '\x99',
#  'Surprise',
#  'a',
#  'Failure',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXV',
#  '.',
#  'A',
#  'New',
#  'Order',
#  'of',
#  'Thingsâ',
#  '\x80',
#  '\x94',
#  'Poor',
#  'Huckâ',
#  '\x80',
#  '\x94',
#  'New',
#  'Adventures',
#  'Planned',
#  '\x03',
#  '\x02',
#  'ILLUSTRATIONS',
#  '\x03',
#  '\x02',
#  'Tom',
#  'Sawyer',
#  '\x03',
#  '\x02',
#  'Tom',
#  'at',
#  'Home',
#  '\x03',
#  '\x02',
#  'Aunt',
#  'Polly',
#  'Beguiled',
#  '\x03',
#  '\x02',
#  'A',
#  'Good',
#  'Opportunity',
#  '\x03',
#  '\x02',
#  'Whoâ',
#  '\x80',
#  '\x99',
#  's',
#  'Afraid',
#  '\x03',
#  '\x02',
#  'Late',
#  'Home',
#  '\x03',
#  '\x02',
#  'Jim',
#  '\x03',
#  '\x02',
#  'â',
#  '\x80',
#  '\x99',
#  'Tendinâ',
#  '\x80',
#  '\x99',
#  'to',
#  'Business',
#  '\x03',
#  '\x02',
#  'Ainâ',
#  '\x80',
#  '\x99',
#  't',
#  'that',
#  'Work',
#  '?',
#  '\x03',
#  '\x02',
#  'Cat',
#  'and',
#  'Toys',
#  '\x03',
#  '\x02',
#  'Amusement',
#  '\x03',
#  '\x02',
#  'Becky',
#  'Thatcher',
#  '\x03',
#  '\x02',
#  'Paying',
#  'Off',
#  '\x03',
#  '\x02',
#  'After',
#  'the',
#  'Battle',
#  '\x03',
#  '\x02',
#  'â',
#  '\x80',
#  '\x9c',
#  'Showing',
#  'Offâ',
#  '\x80',
#  '\x9d',
#  '\x03',
#  '\x02',
#  'Not',
#  'Amiss',
#  '\x03',
#  '\x02',
#  'Mary',
#  '\x03',
#  '\x02',
#  'Tom',
#  'Contemplating',
#  '\x03',
#  '\x02',
#  'Dampened',
#  'Ardor',
#  '\x03',
#  '\x02',
#  'Youth',
#  '\x03',
#  '\x02',
#  'Boyhood',
#  '\x03',
#  '\x02',
#  'Using',
#  'the',
#  'â',
#  '\x80',
#  '\x9c',
#  'Barlowâ',
#  '\x80',
#  '\x9d',
#  '\x03',
#  '\x02',
#  'The',
#  'Church',
#  '\x03',
#  '\x02',
#  'Necessities',
#  '\x03',
#  '\x02',
#  'Tom',
#  'as',
#  'a',
#  'Sunday',
#  '-',
#  'School',
#  'Hero',
#  '\x03',
#  '\x02',
#  'The',
#  'Prize',
#  '\x03',
#  '\x02',
#  'At',
#  'Church',
#  '\x03',
#  '\x02',
#  'The',
#  'Model',
#  'Boy',
#  '\x03',
#  '\x02',
#  'The',
#  'Church',
#  'Choir',
#  '\x03',
#  '\x02',
#  'A',
#  'Side',
#  'Show',
#  '\x03',
#  '\x02',
#  'Result',
#  'of',
#  'Playing',
#  'in',
#  'Church',
#  '\x03',
#  '\x02',
#  'The',
#  'Pinch',
#  '-',
#  'Bug',
#  '\x03',
#  '\x02',
#  ...]

# %%
tokens = proj.tokenize(book_string)
tokens
# Out:
# ['\x02',
#  'THE',
#  'ADVENTURES',
#  'OF',
#  'TOM',
#  'SAWYER',
#  '\x03',
#  '\x02',
#  'By',
#  'Mark',
#  'Twain',
#  '\x03',
#  '\x02',
#  '(',
#  'Samuel',
#  'Langhorne',
#  'Clemens',
#  ')',
#  '\x03',
#  '\x02',
#  'CONTENTS',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'I',
#  '.',
#  'Y',
#  '-',
#  'o',
#  '-',
#  'u',
#  '-',
#  'u',
#  'Tom',
#  '-',
#  'Aunt',
#  'Polly',
#  'Decides',
#  'Upon',
#  'her',
#  'Dutyâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Practices',
#  'Musicâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Challengeâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Private',
#  'Entrance',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'II',
#  '.',
#  'Strong',
#  'Temptationsâ',
#  '\x80',
#  '\x94',
#  'Strategic',
#  'Movementsâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Innocents',
#  'Beguiled',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'III',
#  '.',
#  'Tom',
#  'as',
#  'a',
#  'Generalâ',
#  '\x80',
#  '\x94',
#  'Triumph',
#  'and',
#  'Rewardâ',
#  '\x80',
#  '\x94',
#  'Dismal',
#  'Felicityâ',
#  '\x80',
#  '\x94',
#  'Commission',
#  'and',
#  'Omission',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'IV',
#  '.',
#  'Mental',
#  'Acrobaticsâ',
#  '\x80',
#  '\x94',
#  'Attending',
#  'Sundayâ',
#  '\x80',
#  '\x94',
#  'Schoolâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Superintendentâ',
#  '\x80',
#  '\x94',
#  'â',
#  '\x80',
#  '\x9c',
#  'Showing',
#  'offâ',
#  '\x80',
#  '\x9d',
#  'â',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Lionized',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'V',
#  '.',
#  'A',
#  'Useful',
#  'Ministerâ',
#  '\x80',
#  '\x94',
#  'In',
#  'Churchâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Climax',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VI',
#  '.',
#  'Self',
#  '-',
#  'Examinationâ',
#  '\x80',
#  '\x94',
#  'Dentistryâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Midnight',
#  'Charmâ',
#  '\x80',
#  '\x94',
#  'Witches',
#  'and',
#  'Devilsâ',
#  '\x80',
#  '\x94',
#  'Cautious',
#  'Approachesâ',
#  '\x80',
#  '\x94',
#  'Happy',
#  'Hours',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VII',
#  '.',
#  'A',
#  'Treaty',
#  'Entered',
#  'Intoâ',
#  '\x80',
#  '\x94',
#  'Early',
#  'Lessonsâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Mistake',
#  'Made',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'VIII',
#  '.',
#  'Tom',
#  'Decides',
#  'on',
#  'his',
#  'Courseâ',
#  '\x80',
#  '\x94',
#  'Old',
#  'Scenes',
#  'Re',
#  '-',
#  'enacted',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'IX',
#  '.',
#  'A',
#  'Solemn',
#  'Situationâ',
#  '\x80',
#  '\x94',
#  'Grave',
#  'Subjects',
#  'Introducedâ',
#  '\x80',
#  '\x94',
#  'Injun',
#  'Joe',
#  'Explains',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'X',
#  '.',
#  'The',
#  'Solemn',
#  'Oathâ',
#  '\x80',
#  '\x94',
#  'Terror',
#  'Brings',
#  'Repentanceâ',
#  '\x80',
#  '\x94',
#  'Mental',
#  'Punishment',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XI',
#  '.',
#  'Muff',
#  'Potter',
#  'Comes',
#  'Himselfâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Conscience',
#  'at',
#  'Work',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XII',
#  '.',
#  'Tom',
#  'Shows',
#  'his',
#  'Generosityâ',
#  '\x80',
#  '\x94',
#  'Aunt',
#  'Polly',
#  'Weakens',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIII',
#  '.',
#  'The',
#  'Young',
#  'Piratesâ',
#  '\x80',
#  '\x94',
#  'Going',
#  'to',
#  'the',
#  'Rendezvousâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Campâ',
#  '\x80',
#  '\x94',
#  'Fire',
#  'Talk',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIV',
#  '.',
#  'Camp',
#  '-',
#  'Lifeâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Sensationâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Steals',
#  'Away',
#  'from',
#  'Camp',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XV',
#  '.',
#  'Tom',
#  'Reconnoitersâ',
#  '\x80',
#  '\x94',
#  'Learns',
#  'the',
#  'Situationâ',
#  '\x80',
#  '\x94',
#  'Reports',
#  'at',
#  'Camp',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVI',
#  '.',
#  'A',
#  'Dayâ',
#  '\x80',
#  '\x99',
#  's',
#  'Amusementsâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Reveals',
#  'a',
#  'Secretâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Pirates',
#  'take',
#  'a',
#  'Lessonâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Night',
#  'Surpriseâ',
#  '\x80',
#  '\x94',
#  'An',
#  'Indian',
#  'War',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVII',
#  '.',
#  'Memories',
#  'of',
#  'the',
#  'Lost',
#  'Heroesâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Point',
#  'in',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Secret',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XVIII',
#  '.',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Feelings',
#  'Investigatedâ',
#  '\x80',
#  '\x94',
#  'Wonderful',
#  'Dreamâ',
#  '\x80',
#  '\x94',
#  'Becky',
#  'Thatcher',
#  'Overshadowedâ',
#  '\x80',
#  '\x94',
#  'Tom',
#  'Becomes',
#  'Jealousâ',
#  '\x80',
#  '\x94',
#  'Black',
#  'Revenge',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XIX',
#  '.',
#  'Tom',
#  'Tells',
#  'the',
#  'Truth',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XX',
#  '.',
#  'Becky',
#  'in',
#  'a',
#  'Dilemmaâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Nobility',
#  'Asserts',
#  'Itself',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXI',
#  '.',
#  'Youthful',
#  'Eloquenceâ',
#  '\x80',
#  '\x94',
#  'Compositions',
#  'by',
#  'the',
#  'Young',
#  'Ladiesâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Lengthy',
#  'Visionâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Boyâ',
#  '\x80',
#  '\x99',
#  's',
#  'Vengeance',
#  'Satisfied',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXII',
#  '.',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Confidence',
#  'Betrayedâ',
#  '\x80',
#  '\x94',
#  'Expects',
#  'Signal',
#  'Punishment',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIII',
#  '.',
#  'Old',
#  'Muffâ',
#  '\x80',
#  '\x99',
#  's',
#  'Friendsâ',
#  '\x80',
#  '\x94',
#  'Muff',
#  'Potter',
#  'in',
#  'Courtâ',
#  '\x80',
#  '\x94',
#  'Muff',
#  'Potter',
#  'Saved',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIV',
#  '.',
#  'Tom',
#  'as',
#  'the',
#  'Village',
#  'Heroâ',
#  '\x80',
#  '\x94',
#  'Days',
#  'of',
#  'Splendor',
#  'and',
#  'Nights',
#  'of',
#  'Horrorâ',
#  '\x80',
#  '\x94',
#  'Pursuit',
#  'of',
#  'Injun',
#  'Joe',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXV',
#  '.',
#  'About',
#  'Kings',
#  'and',
#  'Diamondsâ',
#  '\x80',
#  '\x94',
#  'Search',
#  'for',
#  'the',
#  'Treasureâ',
#  '\x80',
#  '\x94',
#  'Dead',
#  'People',
#  'and',
#  'Ghosts',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVI',
#  '.',
#  'The',
#  'Haunted',
#  'Houseâ',
#  '\x80',
#  '\x94',
#  'Sleepy',
#  'Ghostsâ',
#  '\x80',
#  '\x94',
#  'A',
#  'Box',
#  'of',
#  'Goldâ',
#  '\x80',
#  '\x94',
#  'Bitter',
#  'Luck',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVII',
#  '.',
#  'Doubts',
#  'to',
#  'be',
#  'Settledâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Young',
#  'Detectives',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXVIII',
#  '.',
#  'An',
#  'Attempt',
#  'at',
#  'No',
#  '.',
#  'Twoâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'Mounts',
#  'Guard',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXIX',
#  '.',
#  'The',
#  'Pic',
#  '-',
#  'nicâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'on',
#  'Injun',
#  'Joeâ',
#  '\x80',
#  '\x99',
#  's',
#  'Trackâ',
#  '\x80',
#  '\x94',
#  'The',
#  'â',
#  '\x80',
#  '\x9c',
#  'Revengeâ',
#  '\x80',
#  '\x9d',
#  'Jobâ',
#  '\x80',
#  '\x94',
#  'Aid',
#  'for',
#  'the',
#  'Widow',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXX',
#  '.',
#  'The',
#  'Welshman',
#  'Reportsâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'Under',
#  'Fireâ',
#  '\x80',
#  '\x94',
#  'The',
#  'Story',
#  'Circulated',
#  'â',
#  '\x80',
#  '\x94',
#  'A',
#  'New',
#  'Sensationâ',
#  '\x80',
#  '\x94',
#  'Hope',
#  'Giving',
#  'Way',
#  'to',
#  'Despair',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXI',
#  '.',
#  'An',
#  'Exploring',
#  'Expeditionâ',
#  '\x80',
#  '\x94',
#  'Trouble',
#  'Commencesâ',
#  '\x80',
#  '\x94',
#  'Lost',
#  'in',
#  'the',
#  'Caveâ',
#  '\x80',
#  '\x94',
#  'Total',
#  'Darknessâ',
#  '\x80',
#  '\x94',
#  'Found',
#  'but',
#  'not',
#  'Saved',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXII',
#  '.',
#  'Tom',
#  'tells',
#  'the',
#  'Story',
#  'of',
#  'their',
#  'Escapeâ',
#  '\x80',
#  '\x94',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  's',
#  'Enemy',
#  'in',
#  'Safe',
#  'Quarters',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXIII',
#  '.',
#  'The',
#  'Fate',
#  'of',
#  'Injun',
#  'Joeâ',
#  '\x80',
#  '\x94',
#  'Huck',
#  'and',
#  'Tom',
#  'Compare',
#  'Notes',
#  'â',
#  '\x80',
#  '\x94',
#  'An',
#  'Expedition',
#  'to',
#  'the',
#  'Caveâ',
#  '\x80',
#  '\x94',
#  'Protection',
#  'Against',
#  'Ghostsâ',
#  '\x80',
#  '\x94',
#  'â',
#  '\x80',
#  '\x9c',
#  'An',
#  'Awful',
#  'Snug',
#  'Placeâ',
#  '\x80',
#  '\x9d',
#  'â',
#  '\x80',
#  '\x94',
#  'A',
#  'Reception',
#  'at',
#  'the',
#  'Widow',
#  'Douglasâ',
#  '\x80',
#  '\x99',
#  's',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXIV',
#  '.',
#  'Springing',
#  'a',
#  'Secretâ',
#  '\x80',
#  '\x94',
#  'Mr',
#  '.',
#  'Jonesâ',
#  '\x80',
#  '\x99',
#  'Surprise',
#  'a',
#  'Failure',
#  '\x03',
#  '\x02',
#  'CHAPTER',
#  'XXXV',
#  '.',
#  'A',
#  'New',
#  'Order',
#  'of',
#  'Thingsâ',
#  '\x80',
#  '\x94',
#  'Poor',
#  'Huckâ',
#  '\x80',
#  '\x94',
#  'New',
#  'Adventures',
#  'Planned',
#  '\x03',
#  '\x02',
#  'ILLUSTRATIONS',
#  '\x03',
#  '\x02',
#  'Tom',
#  'Sawyer',
#  '\x03',
#  '\x02',
#  'Tom',
#  'at',
#  'Home',
#  '\x03',
#  '\x02',
#  'Aunt',
#  'Polly',
#  'Beguiled',
#  '\x03',
#  '\x02',
#  'A',
#  'Good',
#  'Opportunity',
#  '\x03',
#  '\x02',
#  'Whoâ',
#  '\x80',
#  '\x99',
#  's',
#  'Afraid',
#  '\x03',
#  '\x02',
#  'Late',
#  'Home',
#  '\x03',
#  '\x02',
#  'Jim',
#  '\x03',
#  '\x02',
#  'â',
#  '\x80',
#  '\x99',
#  'Tendinâ',
#  '\x80',
#  '\x99',
#  'to',
#  'Business',
#  '\x03',
#  '\x02',
#  'Ainâ',
#  '\x80',
#  '\x99',
#  't',
#  'that',
#  'Work',
#  '?',
#  '\x03',
#  '\x02',
#  'Cat',
#  'and',
#  'Toys',
#  '\x03',
#  '\x02',
#  'Amusement',
#  '\x03',
#  '\x02',
#  'Becky',
#  'Thatcher',
#  '\x03',
#  '\x02',
#  'Paying',
#  'Off',
#  '\x03',
#  '\x02',
#  'After',
#  'the',
#  'Battle',
#  '\x03',
#  '\x02',
#  'â',
#  '\x80',
#  '\x9c',
#  'Showing',
#  'Offâ',
#  '\x80',
#  '\x9d',
#  '\x03',
#  '\x02',
#  'Not',
#  'Amiss',
#  '\x03',
#  '\x02',
#  'Mary',
#  '\x03',
#  '\x02',
#  'Tom',
#  'Contemplating',
#  '\x03',
#  '\x02',
#  'Dampened',
#  'Ardor',
#  '\x03',
#  '\x02',
#  'Youth',
#  '\x03',
#  '\x02',
#  'Boyhood',
#  '\x03',
#  '\x02',
#  'Using',
#  'the',
#  'â',
#  '\x80',
#  '\x9c',
#  'Barlowâ',
#  '\x80',
#  '\x9d',
#  '\x03',
#  '\x02',
#  'The',
#  'Church',
#  '\x03',
#  '\x02',
#  'Necessities',
#  '\x03',
#  '\x02',
#  'Tom',
#  'as',
#  'a',
#  'Sunday',
#  '-',
#  'School',
#  'Hero',
#  '\x03',
#  '\x02',
#  'The',
#  'Prize',
#  '\x03',
#  '\x02',
#  'At',
#  'Church',
#  '\x03',
#  '\x02',
#  'The',
#  'Model',
#  'Boy',
#  '\x03',
#  '\x02',
#  'The',
#  'Church',
#  'Choir',
#  '\x03',
#  '\x02',
#  'A',
#  'Side',
#  'Show',
#  '\x03',
#  '\x02',
#  'Result',
#  'of',
#  'Playing',
#  'in',
#  'Church',
#  '\x03',
#  '\x02',
#  'The',
#  'Pinch',
#  '-',
#  'Bug',
#  '\x03',
#  '\x02',
#  'Sid',
#  '\x03',
#  '\x02',
#  'Dentistry',
#  '\x03',
#  '\x02',
#  'Huckleberry',
#  'Finn',
#  '\x03',
#  '\x02',
#  'Mother',
#  'Hopkins',
#  '\x03',
#  '\x02',
#  'Result',
#  'of',
#  'Tomâ',
#  '\x80',
#  '\x99',
#  ...]

# %%
test_list = re.split('(\W)', re.sub(r'\n{2,}', ' \x03 \x02 ', shakespeare).replace(r'\n{1}', ' '))
[i for i in test_list if (i != ' ' and i != '')][1:-1]
# Out:
# ['\x02',
#  'The',
#  'Complete',
#  'Works',
#  'of',
#  'William',
#  'Shakespeare',
#  '\x03',
#  '\x02',
#  'by',
#  'William',
#  'Shakespeare',
#  '\x03',
#  '\x02',
#  'Contents',
#  '\x03',
#  '\x02',
#  'THE',
#  'SONNETS',
#  '\x03',
#  '\x02',
#  'ALL',
#  '’',
#  'S',
#  'WELL',
#  'THAT',
#  'ENDS',
#  'WELL',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'ANTONY',
#  'AND',
#  'CLEOPATRA',
#  '\x03',
#  '\x02',
#  'AS',
#  'YOU',
#  'LIKE',
#  'IT',
#  '\x03',
#  '\x02',
#  'THE',
#  'COMEDY',
#  'OF',
#  'ERRORS',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'CORIOLANUS',
#  '\x03',
#  '\x02',
#  'CYMBELINE',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'HAMLET',
#  ',',
#  'PRINCE',
#  'OF',
#  'DENMARK',
#  '\x03',
#  '\x02',
#  'THE',
#  'FIRST',
#  'PART',
#  'OF',
#  'KING',
#  'HENRY',
#  'THE',
#  'FOURTH',
#  '\x03',
#  '\x02',
#  'THE',
#  'SECOND',
#  'PART',
#  'OF',
#  'KING',
#  'HENRY',
#  'THE',
#  'FOURTH',
#  '\x03',
#  '\x02',
#  'THE',
#  'LIFE',
#  'OF',
#  'KING',
#  'HENRY',
#  'THE',
#  'FIFTH',
#  '\x03',
#  '\x02',
#  'THE',
#  'FIRST',
#  'PART',
#  'OF',
#  'HENRY',
#  'THE',
#  'SIXTH',
#  '\x03',
#  '\x02',
#  'THE',
#  'SECOND',
#  'PART',
#  'OF',
#  'KING',
#  'HENRY',
#  'THE',
#  'SIXTH',
#  '\x03',
#  '\x02',
#  'THE',
#  'THIRD',
#  'PART',
#  'OF',
#  'KING',
#  'HENRY',
#  'THE',
#  'SIXTH',
#  '\x03',
#  '\x02',
#  'KING',
#  'HENRY',
#  'THE',
#  'EIGHTH',
#  '\x03',
#  '\x02',
#  'KING',
#  'JOHN',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'JULIUS',
#  'CAESAR',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'KING',
#  'LEAR',
#  '\x03',
#  '\x02',
#  'LOVE',
#  '’',
#  'S',
#  'LABOUR',
#  '’',
#  'S',
#  'LOST',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'MACBETH',
#  '\x03',
#  '\x02',
#  'MEASURE',
#  'FOR',
#  'MEASURE',
#  '\x03',
#  '\x02',
#  'THE',
#  'MERCHANT',
#  'OF',
#  'VENICE',
#  '\x03',
#  '\x02',
#  'THE',
#  'MERRY',
#  'WIVES',
#  'OF',
#  'WINDSOR',
#  '\x03',
#  '\x02',
#  'A',
#  'MIDSUMMER',
#  'NIGHT',
#  '’',
#  'S',
#  'DREAM',
#  '\x03',
#  '\x02',
#  'MUCH',
#  'ADO',
#  'ABOUT',
#  'NOTHING',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'OTHELLO',
#  ',',
#  'MOOR',
#  'OF',
#  'VENICE',
#  '\x03',
#  '\x02',
#  'PERICLES',
#  ',',
#  'PRINCE',
#  'OF',
#  'TYRE',
#  '\x03',
#  '\x02',
#  'KING',
#  'RICHARD',
#  'THE',
#  'SECOND',
#  '\x03',
#  '\x02',
#  'KING',
#  'RICHARD',
#  'THE',
#  'THIRD',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'ROMEO',
#  'AND',
#  'JULIET',
#  '\x03',
#  '\x02',
#  'THE',
#  'TAMING',
#  'OF',
#  'THE',
#  'SHREW',
#  '\x03',
#  '\x02',
#  'THE',
#  'TEMPEST',
#  '\x03',
#  '\x02',
#  'THE',
#  'LIFE',
#  'OF',
#  'TIMON',
#  'OF',
#  'ATHENS',
#  '\x03',
#  '\x02',
#  'THE',
#  'TRAGEDY',
#  'OF',
#  'TITUS',
#  'ANDRONICUS',
#  '\x03',
#  '\x02',
#  'THE',
#  'HISTORY',
#  'OF',
#  'TROILUS',
#  'AND',
#  'CRESSIDA',
#  '\x03',
#  '\x02',
#  'TWELFTH',
#  'NIGHT',
#  ';',
#  'OR',
#  ',',
#  'WHAT',
#  'YOU',
#  'WILL',
#  '\x03',
#  '\x02',
#  'THE',
#  'TWO',
#  'GENTLEMEN',
#  'OF',
#  'VERONA',
#  '\x03',
#  '\x02',
#  'THE',
#  'TWO',
#  'NOBLE',
#  'KINSMEN',
#  '\x03',
#  '\x02',
#  'THE',
#  'WINTER',
#  '’',
#  'S',
#  'TALE',
#  '\x03',
#  '\x02',
#  'A',
#  'LOVER',
#  '’',
#  'S',
#  'COMPLAINT',
#  '\x03',
#  '\x02',
#  'THE',
#  'PASSIONATE',
#  'PILGRIM',
#  '\x03',
#  '\x02',
#  'THE',
#  'PHOENIX',
#  'AND',
#  'THE',
#  'TURTLE',
#  '\x03',
#  '\x02',
#  'THE',
#  'RAPE',
#  'OF',
#  'LUCRECE',
#  '\x03',
#  '\x02',
#  'VENUS',
#  'AND',
#  'ADONIS',
#  '\x03',
#  '\x02',
#  'THE',
#  'SONNETS',
#  '\x03',
#  '\x02',
#  '1',
#  '\x03',
#  '\x02',
#  'From',
#  'fairest',
#  'creatures',
#  'we',
#  'desire',
#  'increase',
#  ',',
#  '\n',
#  'That',
#  'thereby',
#  'beauty',
#  '’',
#  's',
#  'rose',
#  'might',
#  'never',
#  'die',
#  ',',
#  '\n',
#  'But',
#  'as',
#  'the',
#  'riper',
#  'should',
#  'by',
#  'time',
#  'decease',
#  ',',
#  '\n',
#  'His',
#  'tender',
#  'heir',
#  'might',
#  'bear',
#  'his',
#  'memory',
#  ':',
#  '\n',
#  'But',
#  'thou',
#  'contracted',
#  'to',
#  'thine',
#  'own',
#  'bright',
#  'eyes',
#  ',',
#  '\n',
#  'Feed',
#  '’',
#  'st',
#  'thy',
#  'light',
#  '’',
#  's',
#  'flame',
#  'with',
#  'self',
#  '-',
#  'substantial',
#  'fuel',
#  ',',
#  '\n',
#  'Making',
#  'a',
#  'famine',
#  'where',
#  'abundance',
#  'lies',
#  ',',
#  '\n',
#  'Thy',
#  'self',
#  'thy',
#  'foe',
#  ',',
#  'to',
#  'thy',
#  'sweet',
#  'self',
#  'too',
#  'cruel',
#  ':',
#  '\n',
#  'Thou',
#  'that',
#  'art',
#  'now',
#  'the',
#  'world',
#  '’',
#  's',
#  'fresh',
#  'ornament',
#  ',',
#  '\n',
#  'And',
#  'only',
#  'herald',
#  'to',
#  'the',
#  'gaudy',
#  'spring',
#  ',',
#  '\n',
#  'Within',
#  'thine',
#  'own',
#  'bud',
#  'buriest',
#  'thy',
#  'content',
#  ',',
#  '\n',
#  'And',
#  ',',
#  'tender',
#  'churl',
#  ',',
#  'mak',
#  '’',
#  'st',
#  'waste',
#  'in',
#  'niggarding',
#  ':',
#  '\n',
#  'Pity',
#  'the',
#  'world',
#  ',',
#  'or',
#  'else',
#  'this',
#  'glutton',
#  'be',
#  ',',
#  '\n',
#  'To',
#  'eat',
#  'the',
#  'world',
#  '’',
#  's',
#  'due',
#  ',',
#  'by',
#  'the',
#  'grave',
#  'and',
#  'thee',
#  '.',
#  '\x03',
#  '\x02',
#  '2',
#  '\x03',
#  '\x02',
#  'When',
#  'forty',
#  'winters',
#  'shall',
#  'besiege',
#  'thy',
#  'brow',
#  ',',
#  '\n',
#  'And',
#  'dig',
#  'deep',
#  'trenches',
#  'in',
#  'thy',
#  'beauty',
#  '’',
#  's',
#  'field',
#  ',',
#  '\n',
#  'Thy',
#  'youth',
#  '’',
#  's',
#  'proud',
#  'livery',
#  'so',
#  'gazed',
#  'on',
#  'now',
#  ',',
#  '\n',
#  'Will',
#  'be',
#  'a',
#  'tattered',
#  'weed',
#  'of',
#  'small',
#  'worth',
#  'held',
#  ':',
#  '\n',
#  'Then',
#  'being',
#  'asked',
#  ',',
#  'where',
#  'all',
#  'thy',
#  'beauty',
#  'lies',
#  ',',
#  '\n',
#  'Where',
#  'all',
#  'the',
#  'treasure',
#  'of',
#  'thy',
#  'lusty',
#  'days',
#  ';',
#  '\n',
#  'To',
#  'say',
#  ',',
#  'within',
#  'thine',
#  'own',
#  'deep',
#  'sunken',
#  'eyes',
#  ',',
#  '\n',
#  'Were',
#  'an',
#  'all',
#  '-',
#  'eating',
#  'shame',
#  ',',
#  'and',
#  'thriftless',
#  'praise',
#  '.',
#  '\n',
#  'How',
#  'much',
#  'more',
#  'praise',
#  'deserv',
#  '’',
#  'd',
#  'thy',
#  'beauty',
#  '’',
#  's',
#  'use',
#  ',',
#  '\n',
#  'If',
#  'thou',
#  'couldst',
#  'answer',
#  '‘',
#  'This',
#  'fair',
#  'child',
#  'of',
#  'mine',
#  '\n',
#  'Shall',
#  'sum',
#  'my',
#  'count',
#  ',',
#  'and',
#  'make',
#  'my',
#  'old',
#  'excuse',
#  ',',
#  '’',
#  '\n',
#  'Proving',
#  'his',
#  'beauty',
#  'by',
#  'succession',
#  'thine',
#  '.',
#  '\n',
#  'This',
#  'were',
#  'to',
#  'be',
#  'new',
#  'made',
#  'when',
#  'thou',
#  'art',
#  'old',
#  ',',
#  '\n',
#  'And',
#  'see',
#  'thy',
#  'blood',
#  'warm',
#  'when',
#  'thou',
#  'feel',
#  '’',
#  'st',
#  'it',
#  'cold',
#  '.',
#  '\x03',
#  '\x02',
#  '3',
#  '\x03',
#  '\x02',
#  'Look',
#  'in',
#  'thy',
#  'glass',
#  'and',
#  'tell',
#  'the',
#  'face',
#  'thou',
#  'viewest',
#  ',',
#  '\n',
#  'Now',
#  'is',
#  'the',
#  'time',
#  'that',
#  'face',
#  'should',
#  'form',
#  'another',
#  ',',
#  '\n',
#  'Whose',
#  'fresh',
#  'repair',
#  'if',
#  'now',
#  'thou',
#  'not',
#  'renewest',
#  ',',
#  '\n',
#  'Thou',
#  'dost',
#  'beguile',
#  'the',
#  'world',
#  ',',
#  'unbless',
#  'some',
#  'mother',
#  '.',
#  '\n',
#  'For',
#  'where',
#  'is',
#  'she',
#  'so',
#  'fair',
#  'whose',
#  'uneared',
#  'womb',
#  '\n',
#  'Disdains',
#  'the',
#  'tillage',
#  'of',
#  'thy',
#  'husbandry',
#  '?',
#  '\n',
#  'Or',
#  'who',
#  'is',
#  'he',
#  'so',
#  'fond',
#  'will',
#  'be',
#  'the',
#  'tomb',
#  '\n',
#  'Of',
#  'his',
#  'self',
#  '-',
#  'love',
#  'to',
#  'stop',
#  'posterity',
#  '?',
#  '\n',
#  'Thou',
#  'art',
#  'thy',
#  'mother',
#  '’',
#  's',
#  'glass',
#  'and',
#  'she',
#  'in',
#  'thee',
#  '\n',
#  'Calls',
#  'back',
#  'the',
#  'lovely',
#  'April',
#  'of',
#  'her',
#  'prime',
#  ',',
#  '\n',
#  'So',
#  'thou',
#  'through',
#  'windows',
#  'of',
#  'thine',
#  'age',
#  'shalt',
#  'see',
#  ',',
#  '\n',
#  'Despite',
#  'of',
#  'wrinkles',
#  'this',
#  'thy',
#  'golden',
#  'time',
#  '.',
#  '\n',
#  'But',
#  'if',
#  'thou',
#  'live',
#  'remembered',
#  'not',
#  'to',
#  'be',
#  ',',
#  '\n',
#  'Die',
#  'single',
#  'and',
#  'thine',
#  'image',
#  'dies',
#  'with',
#  'thee',
#  '.',
#  '\x03',
#  '\x02',
#  '4',
#  '\x03',
#  '\x02',
#  'Unthrifty',
#  'loveliness',
#  'why',
#  'dost',
#  'thou',
#  'spend',
#  ',',
#  '\n',
#  'Upon',
#  'thy',
#  'self',
#  'thy',
#  'beauty',
#  '’',
#  's',
#  'legacy',
#  '?',
#  '\n',
#  'Nature',
#  '’',
#  's',
#  'bequest',
#  'gives',
#  'nothing',
#  'but',
#  'doth',
#  'lend',
#  ',',
#  '\n',
#  'And',
#  'being',
#  'frank',
#  'she',
#  'lends',
#  'to',
#  'those',
#  'are',
#  'free',
#  ':',
#  '\n',
#  'Then',
#  'beauteous',
#  'niggard',
#  'why',
#  'dost',
#  'thou',
#  'abuse',
#  ',',
#  '\n',
#  'The',
#  'bounteous',
#  'largess',
#  'given',
#  'thee',
#  'to',
#  'give',
#  '?',
#  '\n',
#  'Profitless',
#  'usurer',
#  'why',
#  'dost',
#  'thou',
#  'use',
#  '\n',
#  'So',
#  'great',
#  'a',
#  'sum',
#  'of',
#  'sums',
#  'yet',
#  'canst',
#  'not',
#  'live',
#  '?',
#  '\n',
#  'For',
#  'having',
#  'traffic',
#  'with',
#  'thy',
#  'self',
#  'alone',
#  ',',
#  '\n',
#  'Thou',
#  'of',
#  'thy',
#  'self',
#  'thy',
#  'sweet',
#  'self',
#  'dost',
#  'deceive',
#  ',',
#  '\n',
#  'Then',
#  'how',
#  'when',
#  'nature',
#  'calls',
#  'thee',
#  'to',
#  'be',
#  'gone',
#  ',',
#  '\n',
#  'What',
#  'acceptable',
#  'audit',
#  'canst',
#  'thou',
#  'leave',
#  '?',
#  '\n',
#  'Thy',
#  'unused',
#  'beauty',
#  'must',
#  'be',
#  'tombed',
#  'with',
#  'thee',
#  ',',
#  '\n',
#  'Which',
#  'used',
#  'lives',
#  'th',
#  '’',
#  'executor',
#  'to',
#  'be',
#  '.',
#  '\x03',
#  '\x02',
#  '5',
#  '\x03',
#  '\x02',
#  'Those',
#  'hours',
#  'that',
#  'with',
#  'gentle',
#  'work',
#  'did',
#  'frame',
#  '\n',
#  'The',
#  'lovely',
#  'gaze',
#  'where',
#  'every',
#  'eye',
#  'doth',
#  'dwell',
#  '\n',
#  'Will',
#  'play',
#  'the',
#  'tyrants',
#  'to',
#  'the',
#  'very',
#  'same',
#  ',',
#  '\n',
#  'And',
#  'that',
#  'unfair',
#  'which',
#  'fairly',
#  'doth',
#  'excel',
#  ':',
#  '\n',
#  'For',
#  'never',
#  '-',
#  'resting',
#  'time',
#  'leads',
#  'summer',
#  'on',
#  '\n',
#  'To',
#  'hideous',
#  'winter',
#  'and',
#  'confounds',
#  'him',
#  'there',
#  ',',
#  ...]

# %%
# time your code
# %timeit proj.tokenize(shakespeare)
# Out:
# 706 ms ± 13.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Creating a Language Model
#
# Now that you've learned how to (theoretically) build a language model, you have to implement it in code. Every language model you build will be a class with a few methods in common:
#
# * The `__init__` constructor: when you instantiate an LM object, you will need to pass the 'training corpus' on which your model will be trained (i.e. a list of tokens you created above with `tokenize`). The `train` method will then use that data to create a model which is saved in the `mdl` attribute. This code is given to you.
# * The `train` method takes in a list of tokens (e.g. the output of `tokenize`) and outputs a language model. This language model is usually represented as a `Series` (indexed by tokens; values are probabilities that token occurs), or a `DataFrame`.
# * The `probability` method takes in a sequence of tokens and returns the probability that this sequence occurs under the language model.
# * The `sample` method takes in a number `N > 0` and generates a string made up of `N` tokens using the language model. This method generates language.
#
# You will create three language model classes in the problems below (Uniform; Unigram; N-gram). For each of these, you will implement each of these methods.

# %% [markdown]
# ## Baseline Models: uniform and unigram LMs
#
# ### Uniform probability language model
#
# **Question 3**
#
# A uniform language model is one in which any word is equally likely to appear in any position. The starter code contains a class `UniformLM` which represents a uniform language model. Review the specifics of the class methods above (and in the starter-code) and implement the methods.

# %%
unif = proj.UniformLM(tokens)
unif.sample(100)
# Out:
# 'punches Approachesâ tribe colicky Treaty grandly paraded valance wonderful gory deftly affection easyâ wetting catch architecture mountains treatment personâ throwing intonation function tick goal mossy Judge hookedâ remade dirty Since briskly stony replied earthly shaâ flocking needy Oneâ rail Whose ventured graven nice knownâ Dore wherever _Might_ Somehow ONE sorrowful Palace fascinate coats detective inquiring punctuation obliged danced downstream villagers robbers _honest_ delightful damper Writing Devils depths flight novelty waking killing visiting look public meditation shanty faces indifferent keen Somebody comforted invisible pangs retired howled Praise scufflings Trip claims ordered hendered daily boarded lopped thinking dreadful comet escapade Acrobaticsâ improved'

# %% [markdown]
# ### Unigram language model
#
# **Question 4**
#
# A unigram language model is one in which the likelihood a word appears is proportional to its occurrence in the text. That is, it's just the (unconditional) empirical distribution of words in the corpus. The starter code contains a class `UnigramLM` which represents a unigram language model. Review the specifics of the class methods above (and in the starter-code) and implement the methods.

# %%
unigram = proj.UnigramLM(tokens)
unigram.sample(100)
# Out:
# 'overcome . and \x94 , lowed she \x02 , â of here \x9c , Talk Then \x9d her anybody suds to . the \x80 unwhitewashed ; \x02 of said â Tom . the were \x80 Speak planetâ but thingâ Tom â even boy finest swam track he at \x02 with know And grating by â ! answer sidling â without \x02 \x80 \x94 response \x02 out as \x9d old eyes ! tears All him little a Liquor he his Hucky by by as \x80 \x80 and I \x80 melancholy distance Miller t of Shows , make Thatâ occasioned \x80 mainly'

# %% [markdown]
# ### Conclusion: Baseline models
#
# You've now trained two baseline language models capable of generating new text from a given training text. Attempt to answer these questions for yourself before you continue.
#
# * Which model do you think is better? Why?
# * What are the ways in which both of these models are bad?

# %% [markdown]
# ## N-gram Model
#
# Now you will build an N-gram language model, which we be a little more involved.
#
# **Before continuing, go back and read the introduction to understand the concepts described below.**
#
# The `NGramLM` class contains a few extra methods and attributes beyond those of `UniformLM` and `UnigramLM`:
#
# 1. Instantiating `NGramLM` requires both a list of tokens and an `N > 0`, specifying the `N` in N-grams. This parameter is stored in an attribute `N`.
# 1. The `NGramLM` class has a method `create_ngrams` that takes in a list of tokens and returns a list of N-grams (an N-gram is a `tuple` of length `N`). This list of N-grams is then passed to the `train` method to train the N-gram model.
# 1. The `NGramLM` class has an attribute `mdl` that stores all the n-gram language models for `n=1...N`. The smaller n-grams are needed to compute the likelihood a word occurs at the start of a text. This code is included for you in the constructor.
# 1. While the `train` method still creates a language-model (in this case, an N-gram model), this model is most naturally stored as a DataFrame. This DataFrame will have three columns:
#     - `'ngram'`: containing the n-grams found in the text.
#     - `'n1gram'`: containing the (n-1)-grams upon which the n-grams in `ngram` are built.
#     - `'prob'`: containing the probabilities of each n-gram in `ngram`.

# %% [markdown]
# ### Creating n-grams
#
# **Question 5**
#
# When computing the likelihood that a word occurs in an N-gram model, you compute the probability that word occurs conditional on the (N-1) words that came before it. Therefore, you need to compute a list of N-grams out of your list of tokens (see the introduction for the definition).
#
# Create a method of `NGramLM` called `create_ngrams` that takes in a list of tokens and returns a list of N-grams.

# %%
N = 3

# %%
ngrams = [tuple(tokens[i:i + N]) for i in range(len(tokens) - N + 1)]

# %%
ngrams
# Out:
# [('\x02', 'THE', 'ADVENTURES'),
#  ('THE', 'ADVENTURES', 'OF'),
#  ('ADVENTURES', 'OF', 'TOM'),
#  ('OF', 'TOM', 'SAWYER'),
#  ('TOM', 'SAWYER', '\x03'),
#  ('SAWYER', '\x03', '\x02'),
#  ('\x03', '\x02', 'By'),
#  ('\x02', 'By', 'Mark'),
#  ('By', 'Mark', 'Twain'),
#  ('Mark', 'Twain', '\x03'),
#  ('Twain', '\x03', '\x02'),
#  ('\x03', '\x02', '('),
#  ('\x02', '(', 'Samuel'),
#  ('(', 'Samuel', 'Langhorne'),
#  ('Samuel', 'Langhorne', 'Clemens'),
#  ('Langhorne', 'Clemens', ')'),
#  ('Clemens', ')', '\x03'),
#  (')', '\x03', '\x02'),
#  ('\x03', '\x02', 'CONTENTS'),
#  ('\x02', 'CONTENTS', '\x03'),
#  ('CONTENTS', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'I'),
#  ('CHAPTER', 'I', '.'),
#  ('I', '.', 'Y'),
#  ('.', 'Y', '-'),
#  ('Y', '-', 'o'),
#  ('-', 'o', '-'),
#  ('o', '-', 'u'),
#  ('-', 'u', '-'),
#  ('u', '-', 'u'),
#  ('-', 'u', 'Tom'),
#  ('u', 'Tom', '-'),
#  ('Tom', '-', 'Aunt'),
#  ('-', 'Aunt', 'Polly'),
#  ('Aunt', 'Polly', 'Decides'),
#  ('Polly', 'Decides', 'Upon'),
#  ('Decides', 'Upon', 'her'),
#  ('Upon', 'her', 'Dutyâ'),
#  ('her', 'Dutyâ', '\x80'),
#  ('Dutyâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tom'),
#  ('\x94', 'Tom', 'Practices'),
#  ('Tom', 'Practices', 'Musicâ'),
#  ('Practices', 'Musicâ', '\x80'),
#  ('Musicâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Challengeâ'),
#  ('The', 'Challengeâ', '\x80'),
#  ('Challengeâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Private'),
#  ('A', 'Private', 'Entrance'),
#  ('Private', 'Entrance', '\x03'),
#  ('Entrance', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'II'),
#  ('CHAPTER', 'II', '.'),
#  ('II', '.', 'Strong'),
#  ('.', 'Strong', 'Temptationsâ'),
#  ('Strong', 'Temptationsâ', '\x80'),
#  ('Temptationsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Strategic'),
#  ('\x94', 'Strategic', 'Movementsâ'),
#  ('Strategic', 'Movementsâ', '\x80'),
#  ('Movementsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Innocents'),
#  ('The', 'Innocents', 'Beguiled'),
#  ('Innocents', 'Beguiled', '\x03'),
#  ('Beguiled', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'III'),
#  ('CHAPTER', 'III', '.'),
#  ('III', '.', 'Tom'),
#  ('.', 'Tom', 'as'),
#  ('Tom', 'as', 'a'),
#  ('as', 'a', 'Generalâ'),
#  ('a', 'Generalâ', '\x80'),
#  ('Generalâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Triumph'),
#  ('\x94', 'Triumph', 'and'),
#  ('Triumph', 'and', 'Rewardâ'),
#  ('and', 'Rewardâ', '\x80'),
#  ('Rewardâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Dismal'),
#  ('\x94', 'Dismal', 'Felicityâ'),
#  ('Dismal', 'Felicityâ', '\x80'),
#  ('Felicityâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Commission'),
#  ('\x94', 'Commission', 'and'),
#  ('Commission', 'and', 'Omission'),
#  ('and', 'Omission', '\x03'),
#  ('Omission', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'IV'),
#  ('CHAPTER', 'IV', '.'),
#  ('IV', '.', 'Mental'),
#  ('.', 'Mental', 'Acrobaticsâ'),
#  ('Mental', 'Acrobaticsâ', '\x80'),
#  ('Acrobaticsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Attending'),
#  ('\x94', 'Attending', 'Sundayâ'),
#  ('Attending', 'Sundayâ', '\x80'),
#  ('Sundayâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Schoolâ'),
#  ('\x94', 'Schoolâ', '\x80'),
#  ('Schoolâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Superintendentâ'),
#  ('The', 'Superintendentâ', '\x80'),
#  ('Superintendentâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'â'),
#  ('\x94', 'â', '\x80'),
#  ('â', '\x80', '\x9c'),
#  ('\x80', '\x9c', 'Showing'),
#  ('\x9c', 'Showing', 'offâ'),
#  ('Showing', 'offâ', '\x80'),
#  ('offâ', '\x80', '\x9d'),
#  ('\x80', '\x9d', 'â'),
#  ('\x9d', 'â', '\x80'),
#  ('â', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tom'),
#  ('\x94', 'Tom', 'Lionized'),
#  ('Tom', 'Lionized', '\x03'),
#  ('Lionized', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'V'),
#  ('CHAPTER', 'V', '.'),
#  ('V', '.', 'A'),
#  ('.', 'A', 'Useful'),
#  ('A', 'Useful', 'Ministerâ'),
#  ('Useful', 'Ministerâ', '\x80'),
#  ('Ministerâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'In'),
#  ('\x94', 'In', 'Churchâ'),
#  ('In', 'Churchâ', '\x80'),
#  ('Churchâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Climax'),
#  ('The', 'Climax', '\x03'),
#  ('Climax', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'VI'),
#  ('CHAPTER', 'VI', '.'),
#  ('VI', '.', 'Self'),
#  ('.', 'Self', '-'),
#  ('Self', '-', 'Examinationâ'),
#  ('-', 'Examinationâ', '\x80'),
#  ('Examinationâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Dentistryâ'),
#  ('\x94', 'Dentistryâ', '\x80'),
#  ('Dentistryâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Midnight'),
#  ('The', 'Midnight', 'Charmâ'),
#  ('Midnight', 'Charmâ', '\x80'),
#  ('Charmâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Witches'),
#  ('\x94', 'Witches', 'and'),
#  ('Witches', 'and', 'Devilsâ'),
#  ('and', 'Devilsâ', '\x80'),
#  ('Devilsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Cautious'),
#  ('\x94', 'Cautious', 'Approachesâ'),
#  ('Cautious', 'Approachesâ', '\x80'),
#  ('Approachesâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Happy'),
#  ('\x94', 'Happy', 'Hours'),
#  ('Happy', 'Hours', '\x03'),
#  ('Hours', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'VII'),
#  ('CHAPTER', 'VII', '.'),
#  ('VII', '.', 'A'),
#  ('.', 'A', 'Treaty'),
#  ('A', 'Treaty', 'Entered'),
#  ('Treaty', 'Entered', 'Intoâ'),
#  ('Entered', 'Intoâ', '\x80'),
#  ('Intoâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Early'),
#  ('\x94', 'Early', 'Lessonsâ'),
#  ('Early', 'Lessonsâ', '\x80'),
#  ('Lessonsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Mistake'),
#  ('A', 'Mistake', 'Made'),
#  ('Mistake', 'Made', '\x03'),
#  ('Made', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'VIII'),
#  ('CHAPTER', 'VIII', '.'),
#  ('VIII', '.', 'Tom'),
#  ('.', 'Tom', 'Decides'),
#  ('Tom', 'Decides', 'on'),
#  ('Decides', 'on', 'his'),
#  ('on', 'his', 'Courseâ'),
#  ('his', 'Courseâ', '\x80'),
#  ('Courseâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Old'),
#  ('\x94', 'Old', 'Scenes'),
#  ('Old', 'Scenes', 'Re'),
#  ('Scenes', 'Re', '-'),
#  ('Re', '-', 'enacted'),
#  ('-', 'enacted', '\x03'),
#  ('enacted', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'IX'),
#  ('CHAPTER', 'IX', '.'),
#  ('IX', '.', 'A'),
#  ('.', 'A', 'Solemn'),
#  ('A', 'Solemn', 'Situationâ'),
#  ('Solemn', 'Situationâ', '\x80'),
#  ('Situationâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Grave'),
#  ('\x94', 'Grave', 'Subjects'),
#  ('Grave', 'Subjects', 'Introducedâ'),
#  ('Subjects', 'Introducedâ', '\x80'),
#  ('Introducedâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Injun'),
#  ('\x94', 'Injun', 'Joe'),
#  ('Injun', 'Joe', 'Explains'),
#  ('Joe', 'Explains', '\x03'),
#  ('Explains', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'X'),
#  ('CHAPTER', 'X', '.'),
#  ('X', '.', 'The'),
#  ('.', 'The', 'Solemn'),
#  ('The', 'Solemn', 'Oathâ'),
#  ('Solemn', 'Oathâ', '\x80'),
#  ('Oathâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Terror'),
#  ('\x94', 'Terror', 'Brings'),
#  ('Terror', 'Brings', 'Repentanceâ'),
#  ('Brings', 'Repentanceâ', '\x80'),
#  ('Repentanceâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Mental'),
#  ('\x94', 'Mental', 'Punishment'),
#  ('Mental', 'Punishment', '\x03'),
#  ('Punishment', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XI'),
#  ('CHAPTER', 'XI', '.'),
#  ('XI', '.', 'Muff'),
#  ('.', 'Muff', 'Potter'),
#  ('Muff', 'Potter', 'Comes'),
#  ('Potter', 'Comes', 'Himselfâ'),
#  ('Comes', 'Himselfâ', '\x80'),
#  ('Himselfâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tomâ'),
#  ('\x94', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Conscience'),
#  ('s', 'Conscience', 'at'),
#  ('Conscience', 'at', 'Work'),
#  ('at', 'Work', '\x03'),
#  ('Work', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XII'),
#  ('CHAPTER', 'XII', '.'),
#  ('XII', '.', 'Tom'),
#  ('.', 'Tom', 'Shows'),
#  ('Tom', 'Shows', 'his'),
#  ('Shows', 'his', 'Generosityâ'),
#  ('his', 'Generosityâ', '\x80'),
#  ('Generosityâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Aunt'),
#  ('\x94', 'Aunt', 'Polly'),
#  ('Aunt', 'Polly', 'Weakens'),
#  ('Polly', 'Weakens', '\x03'),
#  ('Weakens', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XIII'),
#  ('CHAPTER', 'XIII', '.'),
#  ('XIII', '.', 'The'),
#  ('.', 'The', 'Young'),
#  ('The', 'Young', 'Piratesâ'),
#  ('Young', 'Piratesâ', '\x80'),
#  ('Piratesâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Going'),
#  ('\x94', 'Going', 'to'),
#  ('Going', 'to', 'the'),
#  ('to', 'the', 'Rendezvousâ'),
#  ('the', 'Rendezvousâ', '\x80'),
#  ('Rendezvousâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Campâ'),
#  ('The', 'Campâ', '\x80'),
#  ('Campâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Fire'),
#  ('\x94', 'Fire', 'Talk'),
#  ('Fire', 'Talk', '\x03'),
#  ('Talk', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XIV'),
#  ('CHAPTER', 'XIV', '.'),
#  ('XIV', '.', 'Camp'),
#  ('.', 'Camp', '-'),
#  ('Camp', '-', 'Lifeâ'),
#  ('-', 'Lifeâ', '\x80'),
#  ('Lifeâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Sensationâ'),
#  ('A', 'Sensationâ', '\x80'),
#  ('Sensationâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tom'),
#  ('\x94', 'Tom', 'Steals'),
#  ('Tom', 'Steals', 'Away'),
#  ('Steals', 'Away', 'from'),
#  ('Away', 'from', 'Camp'),
#  ('from', 'Camp', '\x03'),
#  ('Camp', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XV'),
#  ('CHAPTER', 'XV', '.'),
#  ('XV', '.', 'Tom'),
#  ('.', 'Tom', 'Reconnoitersâ'),
#  ('Tom', 'Reconnoitersâ', '\x80'),
#  ('Reconnoitersâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Learns'),
#  ('\x94', 'Learns', 'the'),
#  ('Learns', 'the', 'Situationâ'),
#  ('the', 'Situationâ', '\x80'),
#  ('Situationâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Reports'),
#  ('\x94', 'Reports', 'at'),
#  ('Reports', 'at', 'Camp'),
#  ('at', 'Camp', '\x03'),
#  ('Camp', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XVI'),
#  ('CHAPTER', 'XVI', '.'),
#  ('XVI', '.', 'A'),
#  ('.', 'A', 'Dayâ'),
#  ('A', 'Dayâ', '\x80'),
#  ('Dayâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Amusementsâ'),
#  ('s', 'Amusementsâ', '\x80'),
#  ('Amusementsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tom'),
#  ('\x94', 'Tom', 'Reveals'),
#  ('Tom', 'Reveals', 'a'),
#  ('Reveals', 'a', 'Secretâ'),
#  ('a', 'Secretâ', '\x80'),
#  ('Secretâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Pirates'),
#  ('The', 'Pirates', 'take'),
#  ('Pirates', 'take', 'a'),
#  ('take', 'a', 'Lessonâ'),
#  ('a', 'Lessonâ', '\x80'),
#  ('Lessonâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Night'),
#  ('A', 'Night', 'Surpriseâ'),
#  ('Night', 'Surpriseâ', '\x80'),
#  ('Surpriseâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'An'),
#  ('\x94', 'An', 'Indian'),
#  ('An', 'Indian', 'War'),
#  ('Indian', 'War', '\x03'),
#  ('War', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XVII'),
#  ('CHAPTER', 'XVII', '.'),
#  ('XVII', '.', 'Memories'),
#  ('.', 'Memories', 'of'),
#  ('Memories', 'of', 'the'),
#  ('of', 'the', 'Lost'),
#  ('the', 'Lost', 'Heroesâ'),
#  ('Lost', 'Heroesâ', '\x80'),
#  ('Heroesâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Point'),
#  ('The', 'Point', 'in'),
#  ('Point', 'in', 'Tomâ'),
#  ('in', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Secret'),
#  ('s', 'Secret', '\x03'),
#  ('Secret', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XVIII'),
#  ('CHAPTER', 'XVIII', '.'),
#  ('XVIII', '.', 'Tomâ'),
#  ('.', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Feelings'),
#  ('s', 'Feelings', 'Investigatedâ'),
#  ('Feelings', 'Investigatedâ', '\x80'),
#  ('Investigatedâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Wonderful'),
#  ('\x94', 'Wonderful', 'Dreamâ'),
#  ('Wonderful', 'Dreamâ', '\x80'),
#  ('Dreamâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Becky'),
#  ('\x94', 'Becky', 'Thatcher'),
#  ('Becky', 'Thatcher', 'Overshadowedâ'),
#  ('Thatcher', 'Overshadowedâ', '\x80'),
#  ('Overshadowedâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tom'),
#  ('\x94', 'Tom', 'Becomes'),
#  ('Tom', 'Becomes', 'Jealousâ'),
#  ('Becomes', 'Jealousâ', '\x80'),
#  ('Jealousâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Black'),
#  ('\x94', 'Black', 'Revenge'),
#  ('Black', 'Revenge', '\x03'),
#  ('Revenge', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XIX'),
#  ('CHAPTER', 'XIX', '.'),
#  ('XIX', '.', 'Tom'),
#  ('.', 'Tom', 'Tells'),
#  ('Tom', 'Tells', 'the'),
#  ('Tells', 'the', 'Truth'),
#  ('the', 'Truth', '\x03'),
#  ('Truth', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XX'),
#  ('CHAPTER', 'XX', '.'),
#  ('XX', '.', 'Becky'),
#  ('.', 'Becky', 'in'),
#  ('Becky', 'in', 'a'),
#  ('in', 'a', 'Dilemmaâ'),
#  ('a', 'Dilemmaâ', '\x80'),
#  ('Dilemmaâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tomâ'),
#  ('\x94', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Nobility'),
#  ('s', 'Nobility', 'Asserts'),
#  ('Nobility', 'Asserts', 'Itself'),
#  ('Asserts', 'Itself', '\x03'),
#  ('Itself', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXI'),
#  ('CHAPTER', 'XXI', '.'),
#  ('XXI', '.', 'Youthful'),
#  ('.', 'Youthful', 'Eloquenceâ'),
#  ('Youthful', 'Eloquenceâ', '\x80'),
#  ('Eloquenceâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Compositions'),
#  ('\x94', 'Compositions', 'by'),
#  ('Compositions', 'by', 'the'),
#  ('by', 'the', 'Young'),
#  ('the', 'Young', 'Ladiesâ'),
#  ('Young', 'Ladiesâ', '\x80'),
#  ('Ladiesâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Lengthy'),
#  ('A', 'Lengthy', 'Visionâ'),
#  ('Lengthy', 'Visionâ', '\x80'),
#  ('Visionâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Boyâ'),
#  ('The', 'Boyâ', '\x80'),
#  ('Boyâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Vengeance'),
#  ('s', 'Vengeance', 'Satisfied'),
#  ('Vengeance', 'Satisfied', '\x03'),
#  ('Satisfied', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXII'),
#  ('CHAPTER', 'XXII', '.'),
#  ('XXII', '.', 'Tomâ'),
#  ('.', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Confidence'),
#  ('s', 'Confidence', 'Betrayedâ'),
#  ('Confidence', 'Betrayedâ', '\x80'),
#  ('Betrayedâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Expects'),
#  ('\x94', 'Expects', 'Signal'),
#  ('Expects', 'Signal', 'Punishment'),
#  ('Signal', 'Punishment', '\x03'),
#  ('Punishment', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXIII'),
#  ('CHAPTER', 'XXIII', '.'),
#  ('XXIII', '.', 'Old'),
#  ('.', 'Old', 'Muffâ'),
#  ('Old', 'Muffâ', '\x80'),
#  ('Muffâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Friendsâ'),
#  ('s', 'Friendsâ', '\x80'),
#  ('Friendsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Muff'),
#  ('\x94', 'Muff', 'Potter'),
#  ('Muff', 'Potter', 'in'),
#  ('Potter', 'in', 'Courtâ'),
#  ('in', 'Courtâ', '\x80'),
#  ('Courtâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Muff'),
#  ('\x94', 'Muff', 'Potter'),
#  ('Muff', 'Potter', 'Saved'),
#  ('Potter', 'Saved', '\x03'),
#  ('Saved', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXIV'),
#  ('CHAPTER', 'XXIV', '.'),
#  ('XXIV', '.', 'Tom'),
#  ('.', 'Tom', 'as'),
#  ('Tom', 'as', 'the'),
#  ('as', 'the', 'Village'),
#  ('the', 'Village', 'Heroâ'),
#  ('Village', 'Heroâ', '\x80'),
#  ('Heroâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Days'),
#  ('\x94', 'Days', 'of'),
#  ('Days', 'of', 'Splendor'),
#  ('of', 'Splendor', 'and'),
#  ('Splendor', 'and', 'Nights'),
#  ('and', 'Nights', 'of'),
#  ('Nights', 'of', 'Horrorâ'),
#  ('of', 'Horrorâ', '\x80'),
#  ('Horrorâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Pursuit'),
#  ('\x94', 'Pursuit', 'of'),
#  ('Pursuit', 'of', 'Injun'),
#  ('of', 'Injun', 'Joe'),
#  ('Injun', 'Joe', '\x03'),
#  ('Joe', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXV'),
#  ('CHAPTER', 'XXV', '.'),
#  ('XXV', '.', 'About'),
#  ('.', 'About', 'Kings'),
#  ('About', 'Kings', 'and'),
#  ('Kings', 'and', 'Diamondsâ'),
#  ('and', 'Diamondsâ', '\x80'),
#  ('Diamondsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Search'),
#  ('\x94', 'Search', 'for'),
#  ('Search', 'for', 'the'),
#  ('for', 'the', 'Treasureâ'),
#  ('the', 'Treasureâ', '\x80'),
#  ('Treasureâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Dead'),
#  ('\x94', 'Dead', 'People'),
#  ('Dead', 'People', 'and'),
#  ('People', 'and', 'Ghosts'),
#  ('and', 'Ghosts', '\x03'),
#  ('Ghosts', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXVI'),
#  ('CHAPTER', 'XXVI', '.'),
#  ('XXVI', '.', 'The'),
#  ('.', 'The', 'Haunted'),
#  ('The', 'Haunted', 'Houseâ'),
#  ('Haunted', 'Houseâ', '\x80'),
#  ('Houseâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Sleepy'),
#  ('\x94', 'Sleepy', 'Ghostsâ'),
#  ('Sleepy', 'Ghostsâ', '\x80'),
#  ('Ghostsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Box'),
#  ('A', 'Box', 'of'),
#  ('Box', 'of', 'Goldâ'),
#  ('of', 'Goldâ', '\x80'),
#  ('Goldâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Bitter'),
#  ('\x94', 'Bitter', 'Luck'),
#  ('Bitter', 'Luck', '\x03'),
#  ('Luck', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXVII'),
#  ('CHAPTER', 'XXVII', '.'),
#  ('XXVII', '.', 'Doubts'),
#  ('.', 'Doubts', 'to'),
#  ('Doubts', 'to', 'be'),
#  ('to', 'be', 'Settledâ'),
#  ('be', 'Settledâ', '\x80'),
#  ('Settledâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Young'),
#  ('The', 'Young', 'Detectives'),
#  ('Young', 'Detectives', '\x03'),
#  ('Detectives', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXVIII'),
#  ('CHAPTER', 'XXVIII', '.'),
#  ('XXVIII', '.', 'An'),
#  ('.', 'An', 'Attempt'),
#  ('An', 'Attempt', 'at'),
#  ('Attempt', 'at', 'No'),
#  ('at', 'No', '.'),
#  ('No', '.', 'Twoâ'),
#  ('.', 'Twoâ', '\x80'),
#  ('Twoâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Huck'),
#  ('\x94', 'Huck', 'Mounts'),
#  ('Huck', 'Mounts', 'Guard'),
#  ('Mounts', 'Guard', '\x03'),
#  ('Guard', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXIX'),
#  ('CHAPTER', 'XXIX', '.'),
#  ('XXIX', '.', 'The'),
#  ('.', 'The', 'Pic'),
#  ('The', 'Pic', '-'),
#  ('Pic', '-', 'nicâ'),
#  ('-', 'nicâ', '\x80'),
#  ('nicâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Huck'),
#  ('\x94', 'Huck', 'on'),
#  ('Huck', 'on', 'Injun'),
#  ('on', 'Injun', 'Joeâ'),
#  ('Injun', 'Joeâ', '\x80'),
#  ('Joeâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Trackâ'),
#  ('s', 'Trackâ', '\x80'),
#  ('Trackâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'â'),
#  ('The', 'â', '\x80'),
#  ('â', '\x80', '\x9c'),
#  ('\x80', '\x9c', 'Revengeâ'),
#  ('\x9c', 'Revengeâ', '\x80'),
#  ('Revengeâ', '\x80', '\x9d'),
#  ('\x80', '\x9d', 'Jobâ'),
#  ('\x9d', 'Jobâ', '\x80'),
#  ('Jobâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Aid'),
#  ('\x94', 'Aid', 'for'),
#  ('Aid', 'for', 'the'),
#  ('for', 'the', 'Widow'),
#  ('the', 'Widow', '\x03'),
#  ('Widow', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXX'),
#  ('CHAPTER', 'XXX', '.'),
#  ('XXX', '.', 'The'),
#  ('.', 'The', 'Welshman'),
#  ('The', 'Welshman', 'Reportsâ'),
#  ('Welshman', 'Reportsâ', '\x80'),
#  ('Reportsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Huck'),
#  ('\x94', 'Huck', 'Under'),
#  ('Huck', 'Under', 'Fireâ'),
#  ('Under', 'Fireâ', '\x80'),
#  ('Fireâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'The'),
#  ('\x94', 'The', 'Story'),
#  ('The', 'Story', 'Circulated'),
#  ('Story', 'Circulated', 'â'),
#  ('Circulated', 'â', '\x80'),
#  ('â', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'New'),
#  ('A', 'New', 'Sensationâ'),
#  ('New', 'Sensationâ', '\x80'),
#  ('Sensationâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Hope'),
#  ('\x94', 'Hope', 'Giving'),
#  ('Hope', 'Giving', 'Way'),
#  ('Giving', 'Way', 'to'),
#  ('Way', 'to', 'Despair'),
#  ('to', 'Despair', '\x03'),
#  ('Despair', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXXI'),
#  ('CHAPTER', 'XXXI', '.'),
#  ('XXXI', '.', 'An'),
#  ('.', 'An', 'Exploring'),
#  ('An', 'Exploring', 'Expeditionâ'),
#  ('Exploring', 'Expeditionâ', '\x80'),
#  ('Expeditionâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Trouble'),
#  ('\x94', 'Trouble', 'Commencesâ'),
#  ('Trouble', 'Commencesâ', '\x80'),
#  ('Commencesâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Lost'),
#  ('\x94', 'Lost', 'in'),
#  ('Lost', 'in', 'the'),
#  ('in', 'the', 'Caveâ'),
#  ('the', 'Caveâ', '\x80'),
#  ('Caveâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Total'),
#  ('\x94', 'Total', 'Darknessâ'),
#  ('Total', 'Darknessâ', '\x80'),
#  ('Darknessâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Found'),
#  ('\x94', 'Found', 'but'),
#  ('Found', 'but', 'not'),
#  ('but', 'not', 'Saved'),
#  ('not', 'Saved', '\x03'),
#  ('Saved', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXXII'),
#  ('CHAPTER', 'XXXII', '.'),
#  ('XXXII', '.', 'Tom'),
#  ('.', 'Tom', 'tells'),
#  ('Tom', 'tells', 'the'),
#  ('tells', 'the', 'Story'),
#  ('the', 'Story', 'of'),
#  ('Story', 'of', 'their'),
#  ('of', 'their', 'Escapeâ'),
#  ('their', 'Escapeâ', '\x80'),
#  ('Escapeâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Tomâ'),
#  ('\x94', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Enemy'),
#  ('s', 'Enemy', 'in'),
#  ('Enemy', 'in', 'Safe'),
#  ('in', 'Safe', 'Quarters'),
#  ('Safe', 'Quarters', '\x03'),
#  ('Quarters', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXXIII'),
#  ('CHAPTER', 'XXXIII', '.'),
#  ('XXXIII', '.', 'The'),
#  ('.', 'The', 'Fate'),
#  ('The', 'Fate', 'of'),
#  ('Fate', 'of', 'Injun'),
#  ('of', 'Injun', 'Joeâ'),
#  ('Injun', 'Joeâ', '\x80'),
#  ('Joeâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Huck'),
#  ('\x94', 'Huck', 'and'),
#  ('Huck', 'and', 'Tom'),
#  ('and', 'Tom', 'Compare'),
#  ('Tom', 'Compare', 'Notes'),
#  ('Compare', 'Notes', 'â'),
#  ('Notes', 'â', '\x80'),
#  ('â', '\x80', '\x94'),
#  ('\x80', '\x94', 'An'),
#  ('\x94', 'An', 'Expedition'),
#  ('An', 'Expedition', 'to'),
#  ('Expedition', 'to', 'the'),
#  ('to', 'the', 'Caveâ'),
#  ('the', 'Caveâ', '\x80'),
#  ('Caveâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Protection'),
#  ('\x94', 'Protection', 'Against'),
#  ('Protection', 'Against', 'Ghostsâ'),
#  ('Against', 'Ghostsâ', '\x80'),
#  ('Ghostsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'â'),
#  ('\x94', 'â', '\x80'),
#  ('â', '\x80', '\x9c'),
#  ('\x80', '\x9c', 'An'),
#  ('\x9c', 'An', 'Awful'),
#  ('An', 'Awful', 'Snug'),
#  ('Awful', 'Snug', 'Placeâ'),
#  ('Snug', 'Placeâ', '\x80'),
#  ('Placeâ', '\x80', '\x9d'),
#  ('\x80', '\x9d', 'â'),
#  ('\x9d', 'â', '\x80'),
#  ('â', '\x80', '\x94'),
#  ('\x80', '\x94', 'A'),
#  ('\x94', 'A', 'Reception'),
#  ('A', 'Reception', 'at'),
#  ('Reception', 'at', 'the'),
#  ('at', 'the', 'Widow'),
#  ('the', 'Widow', 'Douglasâ'),
#  ('Widow', 'Douglasâ', '\x80'),
#  ('Douglasâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', '\x03'),
#  ('s', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXXIV'),
#  ('CHAPTER', 'XXXIV', '.'),
#  ('XXXIV', '.', 'Springing'),
#  ('.', 'Springing', 'a'),
#  ('Springing', 'a', 'Secretâ'),
#  ('a', 'Secretâ', '\x80'),
#  ('Secretâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Mr'),
#  ('\x94', 'Mr', '.'),
#  ('Mr', '.', 'Jonesâ'),
#  ('.', 'Jonesâ', '\x80'),
#  ('Jonesâ', '\x80', '\x99'),
#  ('\x80', '\x99', 'Surprise'),
#  ('\x99', 'Surprise', 'a'),
#  ('Surprise', 'a', 'Failure'),
#  ('a', 'Failure', '\x03'),
#  ('Failure', '\x03', '\x02'),
#  ('\x03', '\x02', 'CHAPTER'),
#  ('\x02', 'CHAPTER', 'XXXV'),
#  ('CHAPTER', 'XXXV', '.'),
#  ('XXXV', '.', 'A'),
#  ('.', 'A', 'New'),
#  ('A', 'New', 'Order'),
#  ('New', 'Order', 'of'),
#  ('Order', 'of', 'Thingsâ'),
#  ('of', 'Thingsâ', '\x80'),
#  ('Thingsâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'Poor'),
#  ('\x94', 'Poor', 'Huckâ'),
#  ('Poor', 'Huckâ', '\x80'),
#  ('Huckâ', '\x80', '\x94'),
#  ('\x80', '\x94', 'New'),
#  ('\x94', 'New', 'Adventures'),
#  ('New', 'Adventures', 'Planned'),
#  ('Adventures', 'Planned', '\x03'),
#  ('Planned', '\x03', '\x02'),
#  ('\x03', '\x02', 'ILLUSTRATIONS'),
#  ('\x02', 'ILLUSTRATIONS', '\x03'),
#  ('ILLUSTRATIONS', '\x03', '\x02'),
#  ('\x03', '\x02', 'Tom'),
#  ('\x02', 'Tom', 'Sawyer'),
#  ('Tom', 'Sawyer', '\x03'),
#  ('Sawyer', '\x03', '\x02'),
#  ('\x03', '\x02', 'Tom'),
#  ('\x02', 'Tom', 'at'),
#  ('Tom', 'at', 'Home'),
#  ('at', 'Home', '\x03'),
#  ('Home', '\x03', '\x02'),
#  ('\x03', '\x02', 'Aunt'),
#  ('\x02', 'Aunt', 'Polly'),
#  ('Aunt', 'Polly', 'Beguiled'),
#  ('Polly', 'Beguiled', '\x03'),
#  ('Beguiled', '\x03', '\x02'),
#  ('\x03', '\x02', 'A'),
#  ('\x02', 'A', 'Good'),
#  ('A', 'Good', 'Opportunity'),
#  ('Good', 'Opportunity', '\x03'),
#  ('Opportunity', '\x03', '\x02'),
#  ('\x03', '\x02', 'Whoâ'),
#  ('\x02', 'Whoâ', '\x80'),
#  ('Whoâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Afraid'),
#  ('s', 'Afraid', '\x03'),
#  ('Afraid', '\x03', '\x02'),
#  ('\x03', '\x02', 'Late'),
#  ('\x02', 'Late', 'Home'),
#  ('Late', 'Home', '\x03'),
#  ('Home', '\x03', '\x02'),
#  ('\x03', '\x02', 'Jim'),
#  ('\x02', 'Jim', '\x03'),
#  ('Jim', '\x03', '\x02'),
#  ('\x03', '\x02', 'â'),
#  ('\x02', 'â', '\x80'),
#  ('â', '\x80', '\x99'),
#  ('\x80', '\x99', 'Tendinâ'),
#  ('\x99', 'Tendinâ', '\x80'),
#  ('Tendinâ', '\x80', '\x99'),
#  ('\x80', '\x99', 'to'),
#  ('\x99', 'to', 'Business'),
#  ('to', 'Business', '\x03'),
#  ('Business', '\x03', '\x02'),
#  ('\x03', '\x02', 'Ainâ'),
#  ('\x02', 'Ainâ', '\x80'),
#  ('Ainâ', '\x80', '\x99'),
#  ('\x80', '\x99', 't'),
#  ('\x99', 't', 'that'),
#  ('t', 'that', 'Work'),
#  ('that', 'Work', '?'),
#  ('Work', '?', '\x03'),
#  ('?', '\x03', '\x02'),
#  ('\x03', '\x02', 'Cat'),
#  ('\x02', 'Cat', 'and'),
#  ('Cat', 'and', 'Toys'),
#  ('and', 'Toys', '\x03'),
#  ('Toys', '\x03', '\x02'),
#  ('\x03', '\x02', 'Amusement'),
#  ('\x02', 'Amusement', '\x03'),
#  ('Amusement', '\x03', '\x02'),
#  ('\x03', '\x02', 'Becky'),
#  ('\x02', 'Becky', 'Thatcher'),
#  ('Becky', 'Thatcher', '\x03'),
#  ('Thatcher', '\x03', '\x02'),
#  ('\x03', '\x02', 'Paying'),
#  ('\x02', 'Paying', 'Off'),
#  ('Paying', 'Off', '\x03'),
#  ('Off', '\x03', '\x02'),
#  ('\x03', '\x02', 'After'),
#  ('\x02', 'After', 'the'),
#  ('After', 'the', 'Battle'),
#  ('the', 'Battle', '\x03'),
#  ('Battle', '\x03', '\x02'),
#  ('\x03', '\x02', 'â'),
#  ('\x02', 'â', '\x80'),
#  ('â', '\x80', '\x9c'),
#  ('\x80', '\x9c', 'Showing'),
#  ('\x9c', 'Showing', 'Offâ'),
#  ('Showing', 'Offâ', '\x80'),
#  ('Offâ', '\x80', '\x9d'),
#  ('\x80', '\x9d', '\x03'),
#  ('\x9d', '\x03', '\x02'),
#  ('\x03', '\x02', 'Not'),
#  ('\x02', 'Not', 'Amiss'),
#  ('Not', 'Amiss', '\x03'),
#  ('Amiss', '\x03', '\x02'),
#  ('\x03', '\x02', 'Mary'),
#  ('\x02', 'Mary', '\x03'),
#  ('Mary', '\x03', '\x02'),
#  ('\x03', '\x02', 'Tom'),
#  ('\x02', 'Tom', 'Contemplating'),
#  ('Tom', 'Contemplating', '\x03'),
#  ('Contemplating', '\x03', '\x02'),
#  ('\x03', '\x02', 'Dampened'),
#  ('\x02', 'Dampened', 'Ardor'),
#  ('Dampened', 'Ardor', '\x03'),
#  ('Ardor', '\x03', '\x02'),
#  ('\x03', '\x02', 'Youth'),
#  ('\x02', 'Youth', '\x03'),
#  ('Youth', '\x03', '\x02'),
#  ('\x03', '\x02', 'Boyhood'),
#  ('\x02', 'Boyhood', '\x03'),
#  ('Boyhood', '\x03', '\x02'),
#  ('\x03', '\x02', 'Using'),
#  ('\x02', 'Using', 'the'),
#  ('Using', 'the', 'â'),
#  ('the', 'â', '\x80'),
#  ('â', '\x80', '\x9c'),
#  ('\x80', '\x9c', 'Barlowâ'),
#  ('\x9c', 'Barlowâ', '\x80'),
#  ('Barlowâ', '\x80', '\x9d'),
#  ('\x80', '\x9d', '\x03'),
#  ('\x9d', '\x03', '\x02'),
#  ('\x03', '\x02', 'The'),
#  ('\x02', 'The', 'Church'),
#  ('The', 'Church', '\x03'),
#  ('Church', '\x03', '\x02'),
#  ('\x03', '\x02', 'Necessities'),
#  ('\x02', 'Necessities', '\x03'),
#  ('Necessities', '\x03', '\x02'),
#  ('\x03', '\x02', 'Tom'),
#  ('\x02', 'Tom', 'as'),
#  ('Tom', 'as', 'a'),
#  ('as', 'a', 'Sunday'),
#  ('a', 'Sunday', '-'),
#  ('Sunday', '-', 'School'),
#  ('-', 'School', 'Hero'),
#  ('School', 'Hero', '\x03'),
#  ('Hero', '\x03', '\x02'),
#  ('\x03', '\x02', 'The'),
#  ('\x02', 'The', 'Prize'),
#  ('The', 'Prize', '\x03'),
#  ('Prize', '\x03', '\x02'),
#  ('\x03', '\x02', 'At'),
#  ('\x02', 'At', 'Church'),
#  ('At', 'Church', '\x03'),
#  ('Church', '\x03', '\x02'),
#  ('\x03', '\x02', 'The'),
#  ('\x02', 'The', 'Model'),
#  ('The', 'Model', 'Boy'),
#  ('Model', 'Boy', '\x03'),
#  ('Boy', '\x03', '\x02'),
#  ('\x03', '\x02', 'The'),
#  ('\x02', 'The', 'Church'),
#  ('The', 'Church', 'Choir'),
#  ('Church', 'Choir', '\x03'),
#  ('Choir', '\x03', '\x02'),
#  ('\x03', '\x02', 'A'),
#  ('\x02', 'A', 'Side'),
#  ('A', 'Side', 'Show'),
#  ('Side', 'Show', '\x03'),
#  ('Show', '\x03', '\x02'),
#  ('\x03', '\x02', 'Result'),
#  ('\x02', 'Result', 'of'),
#  ('Result', 'of', 'Playing'),
#  ('of', 'Playing', 'in'),
#  ('Playing', 'in', 'Church'),
#  ('in', 'Church', '\x03'),
#  ('Church', '\x03', '\x02'),
#  ('\x03', '\x02', 'The'),
#  ('\x02', 'The', 'Pinch'),
#  ('The', 'Pinch', '-'),
#  ('Pinch', '-', 'Bug'),
#  ('-', 'Bug', '\x03'),
#  ('Bug', '\x03', '\x02'),
#  ('\x03', '\x02', 'Sid'),
#  ('\x02', 'Sid', '\x03'),
#  ('Sid', '\x03', '\x02'),
#  ('\x03', '\x02', 'Dentistry'),
#  ('\x02', 'Dentistry', '\x03'),
#  ('Dentistry', '\x03', '\x02'),
#  ('\x03', '\x02', 'Huckleberry'),
#  ('\x02', 'Huckleberry', 'Finn'),
#  ('Huckleberry', 'Finn', '\x03'),
#  ('Finn', '\x03', '\x02'),
#  ('\x03', '\x02', 'Mother'),
#  ('\x02', 'Mother', 'Hopkins'),
#  ('Mother', 'Hopkins', '\x03'),
#  ('Hopkins', '\x03', '\x02'),
#  ('\x03', '\x02', 'Result'),
#  ('\x02', 'Result', 'of'),
#  ('Result', 'of', 'Tomâ'),
#  ('of', 'Tomâ', '\x80'),
#  ('Tomâ', '\x80', '\x99'),
#  ('\x80', '\x99', 's'),
#  ('\x99', 's', 'Truthfulness'),
#  ...]

# %%
n1grams = [x[:-1] for x in ngrams]

# %% [markdown]
# ### Creating the N-gram LM
#
# **Question 6**
#
# Now, you will compute the probabilities that define N-gram language model itself. Recall that the N-gram LM consists of probabilities
# $$P(w_1,\ldots,w_N) = P(w_N | w_1,\ldots, w_{N-1}) = \frac{C(w_1, \ldots, w_N)}{C(w_1,\ldots, w_{N-1})}$$
#
# for every n-gram $(w_1, \ldots, w_N)$ that occurs in the text.
#
# Create a method of `NGramLM` called `train` that takes in a list of N-grams and returns a dataframe of conditional probabilities with the following columns:
#
# * `ngram` contains each N-gram that occurs in the text,
# * `n1gram` contains the (N-1) tokens that precede the last token in the N-gram occupying the same row.
# * `prob` contains the conditional probabilities associated to the N-gram occupying the same row.

# %%
ngrams_ct = pd.Series(ngrams).value_counts()
n1grams_ct = pd.Series(n1grams).value_counts()

# %%
ngrams_ct.index[54]
# Out:
# (',', 'Tom', ',')

# %%
t = (',', 'Tom', ',')

# %%
ngrams_ct[t] / n1grams_ct[t[:-1]]
# Out:
# 0.29375

# %%
n1grams_ct[t[:-1]]
# Out:
# 160

# %%
def assign_prob(row):
    return ngrams_ct[row] / n1grams_ct[row[:-1]]

# %%
res = pd.Series(ngrams_ct.index).apply(assign_prob)
res.index = ngrams_ct.index

# %%
res[('aha', 'just', 'testing')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\Python\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'tuple' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-c88c8f59e39c> in <module>
# ----> 1 res[('aha', 'just', 'testing')]
#
# E:\Python\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# E:\Python\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4417                     raise InvalidIndexError(key)
#    4418                 else:
# -> 4419                     raise e1
#    4420             except Exception:
#    4421                 raise e1
#
# E:\Python\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('aha', 'just', 'testing')

# %% [markdown]
# ### Computing probabilities from the N-gram LM
#
# **Question 7**
#
# Create a method of `NGramLM` called `probability` that takes in a 'sentence' (sequence of tokens) and returns the likelihood of the sentence under the language model (see the introduction of the formulas).
#
# *Remark:* What is the probability of a sentence that contains a 'never before seen' word? What about a 'never before seen' (N-1)-gram? Is this reasonable? (Answer: no, it's not reasonable. Fixing this sort of deficiency is a topic in NLP).

# %% [markdown]
# ### Sampling from the N-gram LM
#
# **Question 8**
#
# As you saw creating the baseline models, sampling from your trained LM provides a way to generate new language. You will code up a `sample` method for `NGramLM` and observe how much better (or worse) the generated language appears when compared to your baseline models.
#
# Create a method of `NGramLM` called `sample` that takes in a number `M > 0` and generates a string of M tokens using the language model. It should begin with a starting token $\texttt{\\x02}$, then generate the following words from the probabilities in `self.mdl` and continue picking words conditional on the previous choice. The first $\texttt{\\x02}$ token should not count toward the total length. Helper functions and recursion will be very helpful.
#
# *Remark:* If you find, at any point, your LM has no words to sample, then you should return the STOP token (`\x03`) and continue until you reach the required length.
#
# *(Fun) Remark:* Try generating text using different values of `N`. What are the differences (qualitatively)? Don't be alarmed if your samples generate strange quasi-coherent sentences; it's just randomness!
#
# *(Fun) Remark:* Try sampling from an `N`-gram model built on books written in different languages (It doesn't even need to be written using the Latin alphabet!)

# %%
ngram = proj.NGramLM(3, tokens)

# %%
print(ngram.sample(50))

# %% [markdown]
# ### Predicting the next word in a sentence
#
# **OPTIONAL QUESTION**
#
# Build a predictor that predicts the most likely word to follow a given sentence. The predictions will be the *maximum likelihood estimate* given by your N-gram model. Recall that your N-gram model contains the probabilities that a token follows an (n-1)-gram; your predictor will pick the token with the highest probability of occurring.
#
# Create a function that takes in an instantiated `NGramLM` object and a list of tokens, and predicts the *most likely token* to follow the list of tokens in the input (according to `NGramLM`).
#
# *Remark:* For which N does this predictor work best? (Determine this by getting a feel for the output, we won't precisely answer this question).
#
# *Remark:* What would this function look like if it were to take in `UniformLM` or `UnigramLM`?

# %% [markdown]
# ## Model Performance Evaluation
#
# **OPTIONAL QUESTION**
#
# This question attempts to answer the question "which choice of `N` is best when creating an N-gram model?"
#
# As you likely noticed when generating text using your N-gram models, the sentences appear to become more coherent as N increases. The naive conclusion would be to make N very large. However, such a choice has a downside that you will investigate.
#
# One concern is that as N gets larger, the distribution of N-grams get more *sparse* -- i.e. the collection of n-grams all have counts close to 1. This makes the language model more likely to merely generate text that was already present in the original text, as opposed to generating *new* language (why?).
#
# In this question, you will quantify this observation: given an N-gram model and a sample of length M, what percentage of (N+1)-grams in the sample are present in the text that was used to create the model?
#
# Create a function which takes in a list of tokens and:
# 1. Generates N-gram models for `N=2,3,4,5,6,7,8` from the given list of tokens,
# 2. Creates samples of length 1000 from each model (remove START/STOP tokens from the samples),
# 3. Calculates the proportion of (N+1)-grams in each sample that were already present in the original list of tokens.
